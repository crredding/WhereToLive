# %%
from datetime import datetime
import matplotlib.pyplot as plt
import meteostat
#https://dev.meteostat.net/python/
from meteostat import units
import pandas as pd
import numpy as np
from time import time
pd.set_option('display.max_columns', 150)
import geopy.distance
# Zipcode boundary datasets
# https://github.com/OpenDataDE/State-zip-code-GeoJSON
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Import Cloudy Data

# %%
cloudy_data = pd.read_csv('DataSets/Weather/zip_lat_lon_wban_cloudiness_data.csv')
cloudy_data['LAT-WBAN'] = cloudy_data['LAT']
cloudy_data['LNG-WBAN'] = cloudy_data['LNG']
cloudy_data['wban-distance-km'] = cloudy_data['wban_distance_km']
def zip_str(row):
    zip_str = str(int(row['ZIP']))
    while len(zip_str) < 5:
        zip_str = '0' + zip_str
    return zip_str
cloudy_data['zip_str'] = cloudy_data.apply(lambda row: zip_str(row), axis =1)
col_to_drop = ['Unnamed: 0', 'Jan CL_zipcode', 'Yrs_zipcode', 'closestWBAN', 
       'Jan PC_zipcode', 'Jan CD_zipcode', 'Feb CL_zipcode', 'Feb PC_zipcode',
       'Feb CD_zipcode', 'Mar CL_zipcode', 'Mar PC_zipcode', 'Mar CD_zipcode',
       'Apr CL_zipcode', 'Apr PC_zipcode', 'Apr CD_zipcode', 'May CL_zipcode',
       'May PC_zipcode', 'May CD_zipcode', 'Jun CL_zipcode', 'Jun PC_zipcode',
       'Jun CD_zipcode', 'Jul CL_zipcode', 'Jul PC_zipcode', 'Jul CD_zipcode',
       'Aug CL_zipcode', 'Aug PC_zipcode', 'Aug CD_zipcode', 'Sept CL_zipcode',
       'Sept PC_zipcode', 'Sept CD_zipcode', 'Oct CL_zipcode',
       'Oct PC_zipcode', 'Oct CD_zipcode', 'Nov CL_zipcode', 'Nov PC_zipcode',
       'Nov CD_zipcode', 'Dec CL_zipcode', 'Dec PC_zipcode', 'Dec CD_zipcode',
       'Ann  CL_zipcode', 'Ann  PC_zipcode', 'Ann  CD_zipcode',
      'State_zipcode', 'City_zipcode', 'LAT_wban', 'LNG_wban', 'LAT', 'LNG',
      'wban_distance_km', 'ZIP']
cloudy_data = cloudy_data.drop(col_to_drop, axis=1)
cloudy_data.columns = [column.split('_')[0] for column in cloudy_data.columns]

# %%
for zip_code in cloudy_data['zip']:
# zip_code = '98037'
    try:
        lat = cloudy_data[cloudy_data['zip'] == zip_code]['LAT'].values[0]
        lng = cloudy_data[cloudy_data['zip'] == zip_code]['LNG'].values[0]

        # wban_zip = ziplatlonwban[ziplatlonwban['zip_str'] == zip_code]
        #Create point for specfied zip_code
        location = meteostat.Point(lat, lng, radius=16000) #weather stations within 16000 meters (~10 miles

        #Set time period
        start = datetime(2019, 1, 1)
        end = datetime(2020, 1, 1)

        start_time = time()

        #Get monthly data
        data = meteostat.Hourly(location, start, end)
        data = data.convert(units.imperial)
        data = data.fetch()

        #Weather condition codes
        # https://dev.meteostat.net/formats.html#weather-condition-codes
        # data['sunny'] = data['coco'] < 3
        # data['rainy'] = (data['coco'] > 6) | (data['prcp'] > 0)

        #Scoping to afternoon data for dwpt calculation
        afternoon = data[(data.index.hour > 11) & (data.index.hour < 19)]
        afternoon_rhum = afternoon.groupby([afternoon.index.month, afternoon.index.day]).mean()['rhum']
        afternoon_rhum.index = afternoon_rhum.index.set_names(['Month', 'Day'])
        afternoon_rhum = afternoon_rhum.reset_index()
        afternoon_rhum_mthly = pd.DataFrame(afternoon_rhum.groupby('Month').mean()['rhum'])
        afternoon_rhum_mthly.columns = ['mthly_afternoon_rhum']

        grouped_by_day = data.groupby([data.index.month, 
                                       data.index.day]).agg({'temp' : ['mean', 'min', 'max', 'count'], 
                                                                        'rhum' : ['mean', 'min', 'max'], 
                                                                        'prcp' : ['sum', 'min', 'count']})
        #                                                                 'rainy' : np.max,
        #                                                                 'sunny' : np.max})

        grouped_by_day.index = grouped_by_day.index.set_names(['Month', 'Day'])
        grouped_by_day = grouped_by_day.reset_index()
        grouped_by_day.columns = ['month', 'day', 'tempmean', 'tempmin', 'tempmax', 'tempcount', 'rhummean', 'rhummin', 'rhummax', 'prcpsum', 'prcpmin', 'prcpcount']#, 'rainymax', 'sunnymax']
        grouped_by_day['over90'] = grouped_by_day['tempmax'] > 90

        grouped_by_month = grouped_by_day.groupby('month').agg({'tempmean' : 'mean',
                                                               'tempmin' : 'mean',
                                                               'tempmax' : 'mean',
                                                               'tempcount' : 'sum',
                                                               'rhummean' : 'mean',
                                                               'rhummin' : 'mean',
                                                               'rhummax' : 'mean',
                                                               'prcpsum' : 'sum',
                                                               'prcpmin' : 'mean',
                                                                'prcpcount' : 'sum',
        #                                                        'rainymax' : 'sum',
        #                                                         'sunnymax' : 'sum',
                                                                'over90' : 'sum'
                                                               })

        season_dict = {1:'winter',
                      2: 'winter',
                      3: 'spring',
                      4: 'spring',
                      5: 'spring',
                      6: 'summer',
                      7: 'summer',
                      8: 'summer',
                      9: 'fall',
                      10:'fall',
                      11:'fall',
                      12:'winter'}

        grouped_by_month['season'] = grouped_by_month.index.map(season_dict)

        grouped_by_month = grouped_by_month.merge(afternoon_rhum_mthly, left_index=True, right_index=True, how='left')

        #calculating temp-humidity index (High is good)
        thi_bins = [-1, 75, 85, 95, 105, 1000]
        grouped_by_month['THI'] = grouped_by_month['tempmean'] - 0.55 * (1 - grouped_by_month['mthly_afternoon_rhum']/100) * (grouped_by_month['tempmean'] - 58)
        grouped_by_month['THI_score'] = pd.cut(grouped_by_month['THI'], thi_bins, labels = [len(thi_bins) - 2 - i for i in range(0, len(thi_bins) - 1)]).astype(int)

        #calculating temp_min index (High is good)
        temp_min_bins = [-1, 15, 25, 35, 45, 1000]
        grouped_by_month['tempmin_score'] = pd.cut(grouped_by_month['tempmin'], temp_min_bins, labels = [i for i in range(0, len(temp_min_bins) - 1)]).astype(int)

        #calculating over90 index (High is good)
        over90_bins = [-1, 3, 6, 9, 12, 15, 20, 1000]
        grouped_by_month['over90_score'] = pd.cut(grouped_by_month['over90'], over90_bins, labels = [len(thi_bins) - i for i in range(0, len(over90_bins) - 1)]).astype(int)

        #calculating rainy index (High is good)
        # rainy_bins = [-1, 3, 6, 10, 15, 20, 25, 1000]
        # grouped_by_month['rainy_score'] = pd.cut(grouped_by_month['rainymax'], rainy_bins, labels = [len(rainy_bins) - 2 - i for i in range(0, len(rainy_bins) - 1)]).astype(int)

        #calculating total rain index (High is good)
        # Not sure if we should include this one...
        rainy_sum_bins = [0.00001, 1, 2, 3, 4, 5, 6, 1000]
        grouped_by_month['rainy_sum_score'] = pd.cut(grouped_by_month['prcpsum'], rainy_sum_bins, labels = [len(rainy_sum_bins) - 2 - i for i in range(0, len(rainy_sum_bins) - 1)])
        # Filling months without rain with slightly penalized score as no one likes a complete desert
        grouped_by_month['rainy_sum_score'] = grouped_by_month['rainy_sum_score'].fillna(len(rainy_sum_bins) - 3).astype(int)

        #Adding in cloudy data
        cloud_score_bins = [0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 70]
        CL_columns = cloudy_data.columns[['CL' in x for x in cloudy_data.columns]]
        PC_columns = cloudy_data.columns[['PC' in x for x in cloudy_data.columns]]
        CD_columns = cloudy_data.columns[['CD' in x for x in cloudy_data.columns]]

        cloudiness_temp = cloudy_data[cloudy_data['zip'] == zip_code][CL_columns].T.reset_index().iloc[:12]
        cloudiness_temp['PC_days'] = cloudy_data[cloudy_data['zip'] == zip_code][PC_columns].T.reset_index().iloc[:12].iloc[:,1:].values
        cloudiness_temp['CD_days'] = cloudy_data[cloudy_data['zip'] == zip_code][CD_columns].T.reset_index().iloc[:12].iloc[:,1:].values
        cloudiness_temp = cloudiness_temp.iloc[:,1:]
        cloudiness_temp.index = [x+1 for x in range(12)]
        cloudiness_temp.columns = ['CL_days', 'PC_days', 'CD_days']
        #Creating cloud score
        cloudiness_temp['CloudScore'] = cloudiness_temp['CL_days'] * 2 + cloudiness_temp['PC_days']
        cloudiness_temp['cloud_score_binned'] = pd.cut(cloudiness_temp['CloudScore'], cloud_score_bins, labels = [i for i in range(0, len(cloud_score_bins) - 1)]).astype(int)

        grouped_by_month = grouped_by_month.merge(cloudiness_temp, how='left', left_index=True, right_index=True)

        # #Adding in sunny data
        # sunny_bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 101]
        # sunny_temp = sunny_perc[sunny_perc['zip_str'] == zip_code].T.reset_index().iloc[:12]
        # sunny_temp = sunny_temp.iloc[:,1:].astype(int)
        # sunny_temp.index = [x+1 for x in range(12)]
        # sunny_temp.columns = ['Sunny_perc']
        # sunny_temp['sunny_score_binned'] = pd.cut(sunny_temp['Sunny_perc'], sunny_bins, labels = [i for i in range(0, len(sunny_bins) - 1)]).astype(int)

        # grouped_by_month = grouped_by_month.merge(sunny_temp, how='left', left_index=True, right_index=True)

        #Calculating weather index
        thi_weight = 30
        mintemp_weight = 5
        over90_weight = 20
        rainy_sum_weight = 5
        cloud_score_weight = 40
        # sunny_perc_weight = 20
        # rainy_day_weight = 5

        max_thi_score = len(thi_bins) - 2
        max_temp_min_score = len(temp_min_bins) - 2
        max_over_90_score = len(over90_bins) - 2
        max_rainy_sum_score = len(rainy_sum_bins) - 2
        max_cloud_score = len(cloud_score_bins) - 2
        # max_sunny_score = len(sunny_bins) - 2
        # max_rainy_score = len(rainy_bins) - 2

        grouped_by_month['WeatherIndex'] = (grouped_by_month['THI_score'] / max_thi_score * thi_weight) \
                                           + (grouped_by_month['tempmin_score'] / max_temp_min_score * mintemp_weight) \
                                           + (grouped_by_month['over90_score'] / max_over_90_score * over90_weight) \
                                           + (grouped_by_month['rainy_sum_score'] / max_rainy_sum_score * rainy_sum_weight) \
                                           + (grouped_by_month['cloud_score_binned'] / max_cloud_score * cloud_score_weight) \
        #                                    + (grouped_by_month['sunny_score_binned'] / max_sunny_score * sunny_perc_weight)
        #                                    + (grouped_by_month['rainy_score'] / max_rainy_score * rainy_day_weight) \


        #Aggregating by season
        grouped_by_season = grouped_by_month.groupby('season').agg({'tempmean' : 'mean',
                                                                'tempmin' : 'mean',
                                                                'tempmax' : 'mean',
                                                                'tempcount' : 'sum',
                                                                'rhummean' : 'mean',
                                                                'rhummin' : 'mean',
                                                                'rhummax' : 'mean',
                                                                'prcpsum' : 'sum',
                                                                'prcpmin' : 'mean',
                                                                'prcpcount' : 'sum',
        #                                                         'rainymax' : 'sum',
        #                                                         'sunnymax' : 'sum',
                                                                'over90' : 'sum',
                                                                'mthly_afternoon_rhum' : 'mean',
                                                                'THI' : 'mean',
                                                                'THI_score' : 'mean',
                                                                'tempmin_score' : 'mean',
                                                                'over90_score' : 'mean', 
        #                                                         'rainy_score' : 'mean',
                                                                'rainy_sum_score' : 'mean',
                                                                'CL_days' : 'sum',
                                                                'PC_days' : 'sum',
                                                                'CD_days' : 'sum',
                                                                'cloud_score_binned' : 'mean',
                                                                'WeatherIndex' : 'mean'
                                                               })
        grouped_by_day.to_csv('DataSets/Weather/Daily/{}_2019daily.csv'.format(zip_code))
        grouped_by_month.to_csv('DataSets/Weather/Monthly/{}_2019monthly.csv'.format(zip_code))
        grouped_by_season.to_csv('DataSets/Weather/Seasonal/{}_2019seasonal.csv'.format(zip_code))

        end_time = time()
        print('Output data for zip: {} in {} ms'.format(zip_code, round(end_time - start_time, 2)))
    except:
        print('BREAK! Unable to output data for zip: {}'.format(zip_code))
        pass

# %% [markdown]
# ### Some of the zipcodes were unable to get information from the meteostat service
# #### Filling in these gaps with the closest zipcode with meteo information

# %%
all_zip_codes = cloudy_data['zip'].values
zips_with_weather = [zipcode[:5] for zipcode in listdir('DataSets/Weather/Daily/')]
zips_without_weather = set(all_zip_codes) - set(zips_with_weather)
zips_without_weather = sorted(zips_without_weather)

# %%
print('{} zipcodes without weather station info'.format(len(zips_without_weather)))
# Out:
# 0 zipcodes without weather station info

# %%
# Getting latlng for zips with missing weather data
ziplatlon = pd.read_csv('DataSets/ziptolat.csv')

def zip_str(row):
    zip_str = str(int(row['ZIP']))
    while len(zip_str) < 5:
        zip_str = '0' + zip_str
    return zip_str

ziplatlon['ZIP'] = ziplatlon.apply(lambda row: zip_str(row), axis = 1)

# %%
zips_without_weather = ziplatlon[ziplatlon['ZIP'].isin(zips_without_weather)].reset_index(drop=True)
zips_with_weather = ziplatlon[ziplatlon['ZIP'].isin(zips_with_weather)].reset_index(drop=True)

# %%
def get_closest_zip_with_weather(input_row):
    try:
        start = time()
        zipcode = input_row['ZIP']
        coord = (input_row['LAT'], input_row['LNG'])

#         zip_code = '40000'
        zip_bracket = 500
        interim_distance_df = zips_with_weather[zips_with_weather['ZIP'].astype(int).between(int(zipcode) - zip_bracket, int(zipcode) + zip_bracket)].copy()
        interim_distance_df['distance'] = interim_distance_df.apply(lambda row: geopy.distance.geodesic(coord,
                                                                                                        (row['LAT'], row['LNG'])).km,
                                                                    axis=1)

        closest_zip_df = interim_distance_df[interim_distance_df['distance'] == interim_distance_df['distance'].min()]
        closest_zip = closest_zip_df['ZIP'].values[0]
        closest_zip_distance = closest_zip_df['distance'].values[0]
        end = time()
        print('Closest zip to {} is {}: {} km. -- {}ms'.format(zipcode, closest_zip, round(closest_zip_distance, 2), round(end-start, 2)))
        return closest_zip + ' ' + str(closest_zip_distance)
    except:
        print('BREAK: couldnt get data for zipcode: {}'.format(zipcode))

zips_without_weather['closest_zip_with_weather'] = zips_without_weather.apply(lambda row: get_closest_zip_with_weather(row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'closest_zip_with_weather'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'closest_zip_with_weather'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-91945f9def7b> in <module>
#      21         print('BREAK: couldnt get data for zipcode: {}'.format(zipcode))
#      22
# ---> 23 zips_without_weather['closest_zip_with_weather'] = zips_without_weather.apply(lambda row: get_closest_zip_with_weather(row), axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3740         # now align rows
#    3741         arraylike = _reindex_for_setitem(value, self.index)
# -> 3742         self._set_item_mgr(key, arraylike)
#    3743
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in new_block(values, placement, ndim, klass)
#    1935
#    1936     values, _ = extract_pandas_array(values, None, ndim)
# -> 1937     check_ndim(values, placement, ndim)
#    1938
#    1939     if klass is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in check_ndim(values, placement, ndim)
#    1978         if len(placement) != len(values):
#    1979             raise ValueError(
# -> 1980                 f"Wrong number of items passed {len(values)}, "
#    1981                 f"placement implies {len(placement)}"
#    1982             )
#
# ValueError: Wrong number of items passed 3, placement implies 1

# %%
zips_without_weather['closet_zip'] = zips_without_weather['closest_zip_with_weather'].str.split(' ').str[0]
zips_without_weather['closest_zip_distance'] = zips_without_weather['closest_zip_with_weather'].str.split(' ').str[1].astype(float)
zips_without_weather
zips_without_weather.head()
# Out:
#      ZIP        LAT         LNG  closest_zip_with_weather closet_zip  \
# 0  58301  48.141947  -98.871697  58259 56.877935707748264      58259
# 1  58311  48.657869  -98.589280   58281 22.10597234872449      58281
# 2  58316  48.824101  -99.777341   58748 66.43855203593469      58748
# 3  58317  48.605338  -99.373909   58239 61.53997714854342      58239
# 4  58318  48.858084 -100.397421  58783 26.743273177119196      58783
#
#    closest_zip_distance
# 0             56.877936
# 1             22.105972
# 2             66.438552
# 3             61.539977
# 4             26.743273

# %%
daily_path = 'DataSets/Weather/Daily/'
monthly_path = 'DataSets/Weather/Monthly/'
season_path = 'DataSets/Weather/Seasonal/'

for index, row in zips_without_weather.iterrows():
    try:
        zipcode = row['ZIP']
        closet_zip = row['closet_zip']

        daily_match = [filename for filename in listdir(daily_path) if closet_zip in filename][0]
        monthly_match = [filename for filename in listdir(monthly_path) if closet_zip in filename][0]
        season_match = [filename for filename in listdir(season_path) if closet_zip in filename][0]

        daily_file = pd.read_csv(daily_path + daily_match).drop('Unnamed: 0', axis=1)
        monthly_file = pd.read_csv(monthly_path + monthly_match, index_col='month')
        season_file = pd.read_csv(season_path + season_match, index_col='season')

        daily_file.to_csv(daily_path + '{}_2019daily.csv'.format(zipcode))
        monthly_file.to_csv(monthly_path + '{}_2019monthly.csv'.format(zipcode))
        season_file.to_csv(season_path + '{}_2019seasonal.csv'.format(zipcode))
        print('Files written for zip: {}'.format(zipcode))
    except:
        print('BREAK: couldnt write data for zipcode: {}'.format(zipcode))
        pass
# Out:
# Files written for zip: 58301
# Files written for zip: 58311
# Files written for zip: 58316
# Files written for zip: 58317
# Files written for zip: 58318
# Files written for zip: 58321
# Files written for zip: 58323
# Files written for zip: 58324
# Files written for zip: 58325
# Files written for zip: 58327
# Files written for zip: 58329
# Files written for zip: 58330
# Files written for zip: 58331
# Files written for zip: 58332
# Files written for zip: 58335
# Files written for zip: 58338
# Files written for zip: 58339
# Files written for zip: 58341
# Files written for zip: 58343
# Files written for zip: 58344
# Files written for zip: 58345
# Files written for zip: 58346
# Files written for zip: 58348
# Files written for zip: 58351
# Files written for zip: 58352
# Files written for zip: 58353
# Files written for zip: 58355
# Files written for zip: 58356
# Files written for zip: 58357
# Files written for zip: 58361
# Files written for zip: 58362
# Files written for zip: 58363
# Files written for zip: 58365
# Files written for zip: 58366
# Files written for zip: 58367
# Files written for zip: 58368
# Files written for zip: 58369
# Files written for zip: 58370
# Files written for zip: 58372
# Files written for zip: 58374
# Files written for zip: 58377
# Files written for zip: 58379
# Files written for zip: 58380
# Files written for zip: 58381
# Files written for zip: 58382
# Files written for zip: 58384
# Files written for zip: 58385
# Files written for zip: 58386
# Files written for zip: 58401
# Files written for zip: 58402
# Files written for zip: 58405
# Files written for zip: 58413
# Files written for zip: 58415
# Files written for zip: 58416
# Files written for zip: 58418
# Files written for zip: 58420
# Files written for zip: 58421
# Files written for zip: 58422
# Files written for zip: 58423
# Files written for zip: 58424
# Files written for zip: 58425
# Files written for zip: 58426
# Files written for zip: 58428
# Files written for zip: 58429
# Files written for zip: 58430
# Files written for zip: 58431
# Files written for zip: 58433
# Files written for zip: 58436
# Files written for zip: 58438
# Files written for zip: 58439
# Files written for zip: 58440
# Files written for zip: 58441
# Files written for zip: 58442
# Files written for zip: 58443
# Files written for zip: 58444
# Files written for zip: 58445
# Files written for zip: 58448
# Files written for zip: 58451
# Files written for zip: 58452
# Files written for zip: 58454
# Files written for zip: 58455
# Files written for zip: 58456
# Files written for zip: 58458
# Files written for zip: 58460
# Files written for zip: 58461
# Files written for zip: 58463
# Files written for zip: 58464
# Files written for zip: 58466
# Files written for zip: 58467
# Files written for zip: 58472
# Files written for zip: 58474
# Files written for zip: 58475
# Files written for zip: 58476
# Files written for zip: 58477
# Files written for zip: 58478
# Files written for zip: 58479
# Files written for zip: 58480
# Files written for zip: 58481
# Files written for zip: 58482
# Files written for zip: 58483
# Files written for zip: 58484
# Files written for zip: 58486
# Files written for zip: 58487
# Files written for zip: 58488
# Files written for zip: 58490
# Files written for zip: 58492
# Files written for zip: 58494
# Files written for zip: 58495
# Files written for zip: 58496
# Files written for zip: 58497
# Files written for zip: 58501

# %% [markdown]
# ## Creating Annual Summaries

# %%
seasonal_path = 'DataSets/Weather/Seasonal/'
annual_path = 'DataSets/Weather/Annual/'

for file in listdir(seasonal_path):
    zip_code = file[:5]
    seasonal_cooked_data = pd.read_csv(seasonal_path + file)
    annual = seasonal_cooked_data.agg({'THI_score' : ['mean', 'min', 'max'],
                                       'tempmin_score': ['mean', 'min', 'max'],
                                       'over90_score' : ['mean', 'min', 'max'],
                                       'rainy_sum_score' : ['mean', 'min', 'max'],
                                       'cloud_score_binned': ['mean', 'min', 'max'],
                                       'WeatherIndex' : ['mean', 'min', 'max']})
    annual.to_csv(annual_path + '{}_2019annual.csv'.format(zip_code))
    print('Output annual data for zip: {}'.format(zip_code))
# Out:
# Output annual data for zip: 00601
# Output annual data for zip: 00602
# Output annual data for zip: 00603
# Output annual data for zip: 00606
# Output annual data for zip: 00610
# Output annual data for zip: 00612
# Output annual data for zip: 00616
# Output annual data for zip: 00617
# Output annual data for zip: 00622
# Output annual data for zip: 00623
# Output annual data for zip: 00624
# Output annual data for zip: 00627
# Output annual data for zip: 00631
# Output annual data for zip: 00637
# Output annual data for zip: 00638
# Output annual data for zip: 00641
# Output annual data for zip: 00646
# Output annual data for zip: 00647
# Output annual data for zip: 00650
# Output annual data for zip: 00652
# Output annual data for zip: 00653
# Output annual data for zip: 00656
# Output annual data for zip: 00659
# Output annual data for zip: 00660
# Output annual data for zip: 00662
# Output annual data for zip: 00664
# Output annual data for zip: 00667
# Output annual data for zip: 00669
# Output annual data for zip: 00670
# Output annual data for zip: 00674
# Output annual data for zip: 00676
# Output annual data for zip: 00677
# Output annual data for zip: 00678
# Output annual data for zip: 00680
# Output annual data for zip: 00682
# Output annual data for zip: 00683
# Output annual data for zip: 00685
# Output annual data for zip: 00687
# Output annual data for zip: 00688
# Output annual data for zip: 00690
# Output annual data for zip: 00692
# Output annual data for zip: 00693
# Output annual data for zip: 00694
# Output annual data for zip: 00698
# Output annual data for zip: 00703
# Output annual data for zip: 00704
# Output annual data for zip: 00705
# Output annual data for zip: 00707
# Output annual data for zip: 00714
# Output annual data for zip: 00715
# Output annual data for zip: 00716
# Output annual data for zip: 00717
# Output annual data for zip: 00718
# Output annual data for zip: 00719
# Output annual data for zip: 00720
# Output annual data for zip: 00723
# Output annual data for zip: 00725
# Output annual data for zip: 00727
# Output annual data for zip: 00728
# Output annual data for zip: 00729
# Output annual data for zip: 00730
# Output annual data for zip: 00731
# Output annual data for zip: 00735
# Output annual data for zip: 00736
# Output annual data for zip: 00738
# Output annual data for zip: 00739
# Output annual data for zip: 00740
# Output annual data for zip: 00741
# Output annual data for zip: 00745
# Output annual data for zip: 00751
# Output annual data for zip: 00754
# Output annual data for zip: 00757
# Output annual data for zip: 00765
# Output annual data for zip: 00766
# Output annual data for zip: 00767
# Output annual data for zip: 00769
# Output annual data for zip: 00771
# Output annual data for zip: 00772
# Output annual data for zip: 00773
# Output annual data for zip: 00775
# Output annual data for zip: 00777
# Output annual data for zip: 00778
# Output annual data for zip: 00780
# Output annual data for zip: 00782
# Output annual data for zip: 00783
# Output annual data for zip: 00784
# Output annual data for zip: 00786
# Output annual data for zip: 00791
# Output annual data for zip: 00794
# Output annual data for zip: 00795
# Output annual data for zip: 00801
# Output annual data for zip: 00802
# Output annual data for zip: 00820
# Output annual data for zip: 00823
# Output annual data for zip: 00824
# Output annual data for zip: 00830
# Output annual data for zip: 00831
# Output annual data for zip: 00840
# Output annual data for zip: 00841
# Output annual data for zip: 00850
# Output annual data for zip: 00851
# Output annual data for zip: 00901
# Output annual data for zip: 00906
# Output annual data for zip: 00907
# Output annual data for zip: 00909
# Output annual data for zip: 00911
# Output annual data for zip: 00912
# Output annual data for zip: 00913
# Output annual data for zip: 00915
# Output annual data for zip: 00917
# Output annual data for zip: 00918
# Output annual data for zip: 00920
# Output annual data for zip: 00921
# Output annual data for zip: 00923
# Output annual data for zip: 00924
# Output annual data for zip: 00925
# Output annual data for zip: 00926
# Output annual data for zip: 00927
# Output annual data for zip: 00934
# Output annual data for zip: 00936
# Output annual data for zip: 00949
# Output annual data for zip: 00950
# Output annual data for zip: 00951
# Output annual data for zip: 00952
# Output annual data for zip: 00953
# Output annual data for zip: 00956
# Output annual data for zip: 00957
# Output annual data for zip: 00959
# Output annual data for zip: 00960
# Output annual data for zip: 00961
# Output annual data for zip: 00962
# Output annual data for zip: 00965
# Output annual data for zip: 00966
# Output annual data for zip: 00968
# Output annual data for zip: 00969
# Output annual data for zip: 00971
# Output annual data for zip: 00976
# Output annual data for zip: 00979
# Output annual data for zip: 00982
# Output annual data for zip: 00983
# Output annual data for zip: 00985
# Output annual data for zip: 00987
# Output annual data for zip: 01001
# Output annual data for zip: 01002
# Output annual data for zip: 01003
# Output annual data for zip: 01005
# Output annual data for zip: 01007
# Output annual data for zip: 01008
# Output annual data for zip: 01009
# Output annual data for zip: 01010
# Output annual data for zip: 01011
# Output annual data for zip: 01012
# Output annual data for zip: 01013
# Output annual data for zip: 01020
# Output annual data for zip: 01022
# Output annual data for zip: 01026
# Output annual data for zip: 01027
# Output annual data for zip: 01028
# Output annual data for zip: 01029
# Output annual data for zip: 01030
# Output annual data for zip: 01031
# Output annual data for zip: 01032
# Output annual data for zip: 01033
# Output annual data for zip: 01034
# Output annual data for zip: 01035
# Output annual data for zip: 01036
# Output annual data for zip: 01037
# Output annual data for zip: 01038
# Output annual data for zip: 01039
# Output annual data for zip: 01040
# Output annual data for zip: 01050
# Output annual data for zip: 01053
# Output annual data for zip: 01054
# Output annual data for zip: 01056
# Output annual data for zip: 01057
# Output annual data for zip: 01060
# Output annual data for zip: 01062
# Output annual data for zip: 01063
# Output annual data for zip: 01066
# Output annual data for zip: 01068
# Output annual data for zip: 01069
# Output annual data for zip: 01070
# Output annual data for zip: 01071
# Output annual data for zip: 01072
# Output annual data for zip: 01073
# Output annual data for zip: 01074
# Output annual data for zip: 01075
# Output annual data for zip: 01077
# Output annual data for zip: 01079
# Output annual data for zip: 01080
# Output annual data for zip: 01081
# Output annual data for zip: 01082
# Output annual data for zip: 01083
# Output annual data for zip: 01084
# Output annual data for zip: 01085
# Output annual data for zip: 01086
# Output annual data for zip: 01088
# Output annual data for zip: 01089
# Output annual data for zip: 01092
# Output annual data for zip: 01093
# Output annual data for zip: 01094
# Output annual data for zip: 01095
# Output annual data for zip: 01096
# Output annual data for zip: 01097
# Output annual data for zip: 01098
# Output annual data for zip: 01103
# Output annual data for zip: 01104
# Output annual data for zip: 01105
# Output annual data for zip: 01106
# Output annual data for zip: 01107
# Output annual data for zip: 01108
# Output annual data for zip: 01109
# Output annual data for zip: 01118
# Output annual data for zip: 01119
# Output annual data for zip: 01128
# Output annual data for zip: 01129
# Output annual data for zip: 01151
# Output annual data for zip: 01199
# Output annual data for zip: 01201
# Output annual data for zip: 01220
# Output annual data for zip: 01222
# Output annual data for zip: 01223
# Output annual data for zip: 01224
# Output annual data for zip: 01225
# Output annual data for zip: 01226
# Output annual data for zip: 01229
# Output annual data for zip: 01230
# Output annual data for zip: 01235
# Output annual data for zip: 01236
# Output annual data for zip: 01237
# Output annual data for zip: 01238
# Output annual data for zip: 01240
# Output annual data for zip: 01242
# Output annual data for zip: 01243
# Output annual data for zip: 01244
# Output annual data for zip: 01245
# Output annual data for zip: 01247
# Output annual data for zip: 01253
# Output annual data for zip: 01254
# Output annual data for zip: 01255
# Output annual data for zip: 01256
# Output annual data for zip: 01257
# Output annual data for zip: 01258
# Output annual data for zip: 01259
# Output annual data for zip: 01260
# Output annual data for zip: 01262
# Output annual data for zip: 01264
# Output annual data for zip: 01266
# Output annual data for zip: 01267
# Output annual data for zip: 01270
# Output annual data for zip: 01301
# Output annual data for zip: 01330
# Output annual data for zip: 01331
# Output annual data for zip: 01337
# Output annual data for zip: 01338
# Output annual data for zip: 01339
# Output annual data for zip: 01340
# Output annual data for zip: 01341
# Output annual data for zip: 01342
# Output annual data for zip: 01343
# Output annual data for zip: 01344
# Output annual data for zip: 01346
# Output annual data for zip: 01347
# Output annual data for zip: 01349
# Output annual data for zip: 01350
# Output annual data for zip: 01351
# Output annual data for zip: 01354
# Output annual data for zip: 01355
# Output annual data for zip: 01360
# Output annual data for zip: 01364
# Output annual data for zip: 01366
# Output annual data for zip: 01367
# Output annual data for zip: 01368
# Output annual data for zip: 01370
# Output annual data for zip: 01373
# Output annual data for zip: 01375
# Output annual data for zip: 01376
# Output annual data for zip: 01378
# Output annual data for zip: 01379
# Output annual data for zip: 01420
# Output annual data for zip: 01430
# Output annual data for zip: 01431
# Output annual data for zip: 01432
# Output annual data for zip: 01434
# Output annual data for zip: 01436
# Output annual data for zip: 01438
# Output annual data for zip: 01440
# Output annual data for zip: 01450
# Output annual data for zip: 01451
# Output annual data for zip: 01452
# Output annual data for zip: 01453
# Output annual data for zip: 01460
# Output annual data for zip: 01462
# Output annual data for zip: 01463
# Output annual data for zip: 01464
# Output annual data for zip: 01467
# Output annual data for zip: 01468
# Output annual data for zip: 01469
# Output annual data for zip: 01473
# Output annual data for zip: 01474
# Output annual data for zip: 01475
# Output annual data for zip: 01501
# Output annual data for zip: 01503
# Output annual data for zip: 01504
# Output annual data for zip: 01505
# Output annual data for zip: 01506
# Output annual data for zip: 01507
# Output annual data for zip: 01510
# Output annual data for zip: 01515
# Output annual data for zip: 01516
# Output annual data for zip: 01518
# Output annual data for zip: 01519
# Output annual data for zip: 01520
# Output annual data for zip: 01521
# Output annual data for zip: 01522
# Output annual data for zip: 01523
# Output annual data for zip: 01524
# Output annual data for zip: 01525
# Output annual data for zip: 01527
# Output annual data for zip: 01529
# Output annual data for zip: 01531
# Output annual data for zip: 01532
# Output annual data for zip: 01534
# Output annual data for zip: 01535
# Output annual data for zip: 01536
# Output annual data for zip: 01537
# Output annual data for zip: 01540
# Output annual data for zip: 01541
# Output annual data for zip: 01542
# Output annual data for zip: 01543
# Output annual data for zip: 01545
# Output annual data for zip: 01550
# Output annual data for zip: 01560
# Output annual data for zip: 01561
# Output annual data for zip: 01562
# Output annual data for zip: 01564
# Output annual data for zip: 01566
# Output annual data for zip: 01568
# Output annual data for zip: 01569
# Output annual data for zip: 01570
# Output annual data for zip: 01571
# Output annual data for zip: 01581
# Output annual data for zip: 01583
# Output annual data for zip: 01585
# Output annual data for zip: 01588
# Output annual data for zip: 01590
# Output annual data for zip: 01602
# Output annual data for zip: 01603
# Output annual data for zip: 01604
# Output annual data for zip: 01605
# Output annual data for zip: 01606
# Output annual data for zip: 01607
# Output annual data for zip: 01608
# Output annual data for zip: 01609
# Output annual data for zip: 01610
# Output annual data for zip: 01611
# Output annual data for zip: 01612
# Output annual data for zip: 01701
# Output annual data for zip: 01702
# Output annual data for zip: 01718
# Output annual data for zip: 01719
# Output annual data for zip: 01720
# Output annual data for zip: 01721
# Output annual data for zip: 01730
# Output annual data for zip: 01731
# Output annual data for zip: 01740
# Output annual data for zip: 01741
# Output annual data for zip: 01742
# Output annual data for zip: 01745
# Output annual data for zip: 01746
# Output annual data for zip: 01747
# Output annual data for zip: 01748
# Output annual data for zip: 01749
# Output annual data for zip: 01752
# Output annual data for zip: 01754
# Output annual data for zip: 01756
# Output annual data for zip: 01757
# Output annual data for zip: 01760
# Output annual data for zip: 01770
# Output annual data for zip: 01772
# Output annual data for zip: 01773
# Output annual data for zip: 01775
# Output annual data for zip: 01776
# Output annual data for zip: 01778
# Output annual data for zip: 01801
# Output annual data for zip: 01803
# Output annual data for zip: 01810
# Output annual data for zip: 01821
# Output annual data for zip: 01824
# Output annual data for zip: 01826
# Output annual data for zip: 01827
# Output annual data for zip: 01830
# Output annual data for zip: 01832
# Output annual data for zip: 01833
# Output annual data for zip: 01834
# Output annual data for zip: 01835
# Output annual data for zip: 01840
# Output annual data for zip: 01841
# Output annual data for zip: 01843
# Output annual data for zip: 01844
# Output annual data for zip: 01845
# Output annual data for zip: 01850
# Output annual data for zip: 01851
# Output annual data for zip: 01852
# Output annual data for zip: 01854
# Output annual data for zip: 01860
# Output annual data for zip: 01862
# Output annual data for zip: 01863
# Output annual data for zip: 01864
# Output annual data for zip: 01867
# Output annual data for zip: 01876
# Output annual data for zip: 01879
# Output annual data for zip: 01880
# Output annual data for zip: 01886
# Output annual data for zip: 01887
# Output annual data for zip: 01890
# Output annual data for zip: 01901
# Output annual data for zip: 01902
# Output annual data for zip: 01904
# Output annual data for zip: 01905
# Output annual data for zip: 01906
# Output annual data for zip: 01907
# Output annual data for zip: 01908
# Output annual data for zip: 01913
# Output annual data for zip: 01915
# Output annual data for zip: 01921
# Output annual data for zip: 01922
# Output annual data for zip: 01923
# Output annual data for zip: 01929
# Output annual data for zip: 01930
# Output annual data for zip: 01937
# Output annual data for zip: 01938
# Output annual data for zip: 01940
# Output annual data for zip: 01944
# Output annual data for zip: 01945
# Output annual data for zip: 01949
# Output annual data for zip: 01950
# Output annual data for zip: 01951
# Output annual data for zip: 01952
# Output annual data for zip: 01960
# Output annual data for zip: 01966
# Output annual data for zip: 01969
# Output annual data for zip: 01970
# Output annual data for zip: 01982
# Output annual data for zip: 01983
# Output annual data for zip: 01984
# Output annual data for zip: 01985
# Output annual data for zip: 02019
# Output annual data for zip: 02021
# Output annual data for zip: 02025
# Output annual data for zip: 02026
# Output annual data for zip: 02030
# Output annual data for zip: 02032
# Output annual data for zip: 02035
# Output annual data for zip: 02038
# Output annual data for zip: 02043
# Output annual data for zip: 02045
# Output annual data for zip: 02047
# Output annual data for zip: 02048
# Output annual data for zip: 02050
# Output annual data for zip: 02052
# Output annual data for zip: 02053
# Output annual data for zip: 02054
# Output annual data for zip: 02056
# Output annual data for zip: 02061
# Output annual data for zip: 02062
# Output annual data for zip: 02066
# Output annual data for zip: 02067
# Output annual data for zip: 02071
# Output annual data for zip: 02072
# Output annual data for zip: 02081
# Output annual data for zip: 02090
# Output annual data for zip: 02093
# Output annual data for zip: 02108
# Output annual data for zip: 02109
# Output annual data for zip: 02110
# Output annual data for zip: 02111
# Output annual data for zip: 02113
# Output annual data for zip: 02114
# Output annual data for zip: 02115
# Output annual data for zip: 02116
# Output annual data for zip: 02118
# Output annual data for zip: 02119
# Output annual data for zip: 02120
# Output annual data for zip: 02121
# Output annual data for zip: 02122
# Output annual data for zip: 02124
# Output annual data for zip: 02125
# Output annual data for zip: 02126
# Output annual data for zip: 02127
# Output annual data for zip: 02128
# Output annual data for zip: 02129
# Output annual data for zip: 02130
# Output annual data for zip: 02131
# Output annual data for zip: 02132
# Output annual data for zip: 02134
# Output annual data for zip: 02135
# Output annual data for zip: 02136
# Output annual data for zip: 02138
# Output annual data for zip: 02139
# Output annual data for zip: 02140
# Output annual data for zip: 02141
# Output annual data for zip: 02142
# Output annual data for zip: 02143
# Output annual data for zip: 02144
# Output annual data for zip: 02145
# Output annual data for zip: 02148
# Output annual data for zip: 02149
# Output annual data for zip: 02150
# Output annual data for zip: 02151
# Output annual data for zip: 02152
# Output annual data for zip: 02155
# Output annual data for zip: 02163
# Output annual data for zip: 02169
# Output annual data for zip: 02170
# Output annual data for zip: 02171
# Output annual data for zip: 02176
# Output annual data for zip: 02180
# Output annual data for zip: 02184
# Output annual data for zip: 02186
# Output annual data for zip: 02188
# Output annual data for zip: 02189
# Output annual data for zip: 02190
# Output annual data for zip: 02191
# Output annual data for zip: 02199
# Output annual data for zip: 02203
# Output annual data for zip: 02210
# Output annual data for zip: 02215
# Output annual data for zip: 02301
# Output annual data for zip: 02302
# Output annual data for zip: 02322
# Output annual data for zip: 02324
# Output annual data for zip: 02330
# Output annual data for zip: 02332
# Output annual data for zip: 02333
# Output annual data for zip: 02338
# Output annual data for zip: 02339
# Output annual data for zip: 02341
# Output annual data for zip: 02343
# Output annual data for zip: 02346
# Output annual data for zip: 02347
# Output annual data for zip: 02351
# Output annual data for zip: 02356
# Output annual data for zip: 02357
# Output annual data for zip: 02359
# Output annual data for zip: 02360
# Output annual data for zip: 02364
# Output annual data for zip: 02366
# Output annual data for zip: 02367
# Output annual data for zip: 02368
# Output annual data for zip: 02370
# Output annual data for zip: 02375
# Output annual data for zip: 02379
# Output annual data for zip: 02382
# Output annual data for zip: 02420
# Output annual data for zip: 02421
# Output annual data for zip: 02445
# Output annual data for zip: 02446
# Output annual data for zip: 02451
# Output annual data for zip: 02452
# Output annual data for zip: 02453
# Output annual data for zip: 02457
# Output annual data for zip: 02458
# Output annual data for zip: 02459
# Output annual data for zip: 02460
# Output annual data for zip: 02461
# Output annual data for zip: 02462
# Output annual data for zip: 02464
# Output annual data for zip: 02465
# Output annual data for zip: 02466
# Output annual data for zip: 02467
# Output annual data for zip: 02468
# Output annual data for zip: 02472
# Output annual data for zip: 02474
# Output annual data for zip: 02476
# Output annual data for zip: 02478
# Output annual data for zip: 02481
# Output annual data for zip: 02482
# Output annual data for zip: 02492
# Output annual data for zip: 02493
# Output annual data for zip: 02494
# Output annual data for zip: 02532
# Output annual data for zip: 02534
# Output annual data for zip: 02535
# Output annual data for zip: 02536
# Output annual data for zip: 02537
# Output annual data for zip: 02538
# Output annual data for zip: 02539
# Output annual data for zip: 02540
# Output annual data for zip: 02542
# Output annual data for zip: 02543
# Output annual data for zip: 02553
# Output annual data for zip: 02554
# Output annual data for zip: 02556
# Output annual data for zip: 02557
# Output annual data for zip: 02558
# Output annual data for zip: 02559
# Output annual data for zip: 02561
# Output annual data for zip: 02562
# Output annual data for zip: 02563
# Output annual data for zip: 02564
# Output annual data for zip: 02568
# Output annual data for zip: 02571
# Output annual data for zip: 02575
# Output annual data for zip: 02576
# Output annual data for zip: 02584
# Output annual data for zip: 02601
# Output annual data for zip: 02630
# Output annual data for zip: 02631
# Output annual data for zip: 02632
# Output annual data for zip: 02633
# Output annual data for zip: 02635
# Output annual data for zip: 02637
# Output annual data for zip: 02638
# Output annual data for zip: 02639
# Output annual data for zip: 02641
# Output annual data for zip: 02642
# Output annual data for zip: 02643
# Output annual data for zip: 02644
# Output annual data for zip: 02645
# Output annual data for zip: 02646
# Output annual data for zip: 02647
# Output annual data for zip: 02648
# Output annual data for zip: 02649
# Output annual data for zip: 02650
# Output annual data for zip: 02651
# Output annual data for zip: 02652
# Output annual data for zip: 02653
# Output annual data for zip: 02655
# Output annual data for zip: 02657
# Output annual data for zip: 02659
# Output annual data for zip: 02660
# Output annual data for zip: 02663
# Output annual data for zip: 02664
# Output annual data for zip: 02666
# Output annual data for zip: 02667
# Output annual data for zip: 02668
# Output annual data for zip: 02669
# Output annual data for zip: 02670
# Output annual data for zip: 02671
# Output annual data for zip: 02672
# Output annual data for zip: 02673
# Output annual data for zip: 02675
# Output annual data for zip: 02702
# Output annual data for zip: 02703
# Output annual data for zip: 02713
# Output annual data for zip: 02715
# Output annual data for zip: 02717
# Output annual data for zip: 02718
# Output annual data for zip: 02719
# Output annual data for zip: 02720
# Output annual data for zip: 02721
# Output annual data for zip: 02723
# Output annual data for zip: 02724
# Output annual data for zip: 02725
# Output annual data for zip: 02726
# Output annual data for zip: 02738
# Output annual data for zip: 02739
# Output annual data for zip: 02740
# Output annual data for zip: 02743
# Output annual data for zip: 02744
# Output annual data for zip: 02745
# Output annual data for zip: 02746
# Output annual data for zip: 02747
# Output annual data for zip: 02748
# Output annual data for zip: 02760
# Output annual data for zip: 02762
# Output annual data for zip: 02763
# Output annual data for zip: 02764
# Output annual data for zip: 02766
# Output annual data for zip: 02767
# Output annual data for zip: 02769
# Output annual data for zip: 02770
# Output annual data for zip: 02771
# Output annual data for zip: 02777
# Output annual data for zip: 02779
# Output annual data for zip: 02780
# Output annual data for zip: 02790
# Output annual data for zip: 02791
# Output annual data for zip: 02802
# Output annual data for zip: 02804
# Output annual data for zip: 02806
# Output annual data for zip: 02807
# Output annual data for zip: 02808
# Output annual data for zip: 02809
# Output annual data for zip: 02812
# Output annual data for zip: 02813
# Output annual data for zip: 02814
# Output annual data for zip: 02815
# Output annual data for zip: 02816
# Output annual data for zip: 02817
# Output annual data for zip: 02818
# Output annual data for zip: 02822
# Output annual data for zip: 02825
# Output annual data for zip: 02826
# Output annual data for zip: 02827
# Output annual data for zip: 02828
# Output annual data for zip: 02830
# Output annual data for zip: 02831
# Output annual data for zip: 02832
# Output annual data for zip: 02833
# Output annual data for zip: 02835
# Output annual data for zip: 02836
# Output annual data for zip: 02837
# Output annual data for zip: 02838
# Output annual data for zip: 02839
# Output annual data for zip: 02840
# Output annual data for zip: 02841
# Output annual data for zip: 02842
# Output annual data for zip: 02852
# Output annual data for zip: 02857
# Output annual data for zip: 02858
# Output annual data for zip: 02859
# Output annual data for zip: 02860
# Output annual data for zip: 02861
# Output annual data for zip: 02863
# Output annual data for zip: 02864
# Output annual data for zip: 02865
# Output annual data for zip: 02871
# Output annual data for zip: 02872
# Output annual data for zip: 02873
# Output annual data for zip: 02874
# Output annual data for zip: 02875
# Output annual data for zip: 02876
# Output annual data for zip: 02878
# Output annual data for zip: 02879
# Output annual data for zip: 02881
# Output annual data for zip: 02882
# Output annual data for zip: 02885
# Output annual data for zip: 02886
# Output annual data for zip: 02888
# Output annual data for zip: 02889
# Output annual data for zip: 02891
# Output annual data for zip: 02892
# Output annual data for zip: 02893
# Output annual data for zip: 02894
# Output annual data for zip: 02895
# Output annual data for zip: 02896
# Output annual data for zip: 02898
# Output annual data for zip: 02903
# Output annual data for zip: 02904
# Output annual data for zip: 02905
# Output annual data for zip: 02906
# Output annual data for zip: 02907
# Output annual data for zip: 02908
# Output annual data for zip: 02909
# Output annual data for zip: 02910
# Output annual data for zip: 02911
# Output annual data for zip: 02912
# Output annual data for zip: 02914
# Output annual data for zip: 02915
# Output annual data for zip: 02916
# Output annual data for zip: 02917
# Output annual data for zip: 02919
# Output annual data for zip: 02920
# Output annual data for zip: 02921
# Output annual data for zip: 03031
# Output annual data for zip: 03032
# Output annual data for zip: 03033
# Output annual data for zip: 03034
# Output annual data for zip: 03036
# Output annual data for zip: 03037
# Output annual data for zip: 03038
# Output annual data for zip: 03042
# Output annual data for zip: 03043
# Output annual data for zip: 03044
# Output annual data for zip: 03045
# Output annual data for zip: 03046
# Output annual data for zip: 03047
# Output annual data for zip: 03048
# Output annual data for zip: 03049
# Output annual data for zip: 03051
# Output annual data for zip: 03052
# Output annual data for zip: 03053
# Output annual data for zip: 03054
# Output annual data for zip: 03055
# Output annual data for zip: 03057
# Output annual data for zip: 03060
# Output annual data for zip: 03062
# Output annual data for zip: 03063
# Output annual data for zip: 03064
# Output annual data for zip: 03070
# Output annual data for zip: 03071
# Output annual data for zip: 03076
# Output annual data for zip: 03077
# Output annual data for zip: 03079
# Output annual data for zip: 03082
# Output annual data for zip: 03084
# Output annual data for zip: 03086
# Output annual data for zip: 03087
# Output annual data for zip: 03101
# Output annual data for zip: 03102
# Output annual data for zip: 03103
# Output annual data for zip: 03104
# Output annual data for zip: 03106
# Output annual data for zip: 03109
# Output annual data for zip: 03110
# Output annual data for zip: 03215
# Output annual data for zip: 03216
# Output annual data for zip: 03217
# Output annual data for zip: 03218
# Output annual data for zip: 03220
# Output annual data for zip: 03221
# Output annual data for zip: 03222
# Output annual data for zip: 03223
# Output annual data for zip: 03224
# Output annual data for zip: 03225
# Output annual data for zip: 03226
# Output annual data for zip: 03227
# Output annual data for zip: 03229
# Output annual data for zip: 03230
# Output annual data for zip: 03231
# Output annual data for zip: 03233
# Output annual data for zip: 03234
# Output annual data for zip: 03235
# Output annual data for zip: 03237
# Output annual data for zip: 03238
# Output annual data for zip: 03240
# Output annual data for zip: 03241
# Output annual data for zip: 03242
# Output annual data for zip: 03243
# Output annual data for zip: 03244
# Output annual data for zip: 03245
# Output annual data for zip: 03246
# Output annual data for zip: 03249
# Output annual data for zip: 03251
# Output annual data for zip: 03253
# Output annual data for zip: 03254
# Output annual data for zip: 03255
# Output annual data for zip: 03256
# Output annual data for zip: 03257
# Output annual data for zip: 03258
# Output annual data for zip: 03259
# Output annual data for zip: 03260
# Output annual data for zip: 03261
# Output annual data for zip: 03262
# Output annual data for zip: 03263
# Output annual data for zip: 03264
# Output annual data for zip: 03266
# Output annual data for zip: 03268
# Output annual data for zip: 03269
# Output annual data for zip: 03273
# Output annual data for zip: 03275
# Output annual data for zip: 03276
# Output annual data for zip: 03278
# Output annual data for zip: 03279
# Output annual data for zip: 03280
# Output annual data for zip: 03281
# Output annual data for zip: 03282
# Output annual data for zip: 03284
# Output annual data for zip: 03285
# Output annual data for zip: 03287
# Output annual data for zip: 03290
# Output annual data for zip: 03291
# Output annual data for zip: 03293
# Output annual data for zip: 03301
# Output annual data for zip: 03303
# Output annual data for zip: 03304
# Output annual data for zip: 03307
# Output annual data for zip: 03431
# Output annual data for zip: 03440
# Output annual data for zip: 03441
# Output annual data for zip: 03442
# Output annual data for zip: 03443
# Output annual data for zip: 03444
# Output annual data for zip: 03445
# Output annual data for zip: 03446
# Output annual data for zip: 03447
# Output annual data for zip: 03448
# Output annual data for zip: 03449
# Output annual data for zip: 03450
# Output annual data for zip: 03451
# Output annual data for zip: 03452
# Output annual data for zip: 03455
# Output annual data for zip: 03456
# Output annual data for zip: 03457
# Output annual data for zip: 03458
# Output annual data for zip: 03461
# Output annual data for zip: 03462
# Output annual data for zip: 03464
# Output annual data for zip: 03465
# Output annual data for zip: 03466
# Output annual data for zip: 03467
# Output annual data for zip: 03470
# Output annual data for zip: 03561
# Output annual data for zip: 03570
# Output annual data for zip: 03574
# Output annual data for zip: 03575
# Output annual data for zip: 03576
# Output annual data for zip: 03579
# Output annual data for zip: 03580
# Output annual data for zip: 03581
# Output annual data for zip: 03582
# Output annual data for zip: 03583
# Output annual data for zip: 03584
# Output annual data for zip: 03585
# Output annual data for zip: 03586
# Output annual data for zip: 03588
# Output annual data for zip: 03590
# Output annual data for zip: 03592
# Output annual data for zip: 03593
# Output annual data for zip: 03595
# Output annual data for zip: 03597
# Output annual data for zip: 03598
# Output annual data for zip: 03601
# Output annual data for zip: 03602
# Output annual data for zip: 03603
# Output annual data for zip: 03604
# Output annual data for zip: 03605
# Output annual data for zip: 03607
# Output annual data for zip: 03608
# Output annual data for zip: 03609
# Output annual data for zip: 03740
# Output annual data for zip: 03741
# Output annual data for zip: 03743
# Output annual data for zip: 03745
# Output annual data for zip: 03746
# Output annual data for zip: 03748
# Output annual data for zip: 03750
# Output annual data for zip: 03751
# Output annual data for zip: 03752
# Output annual data for zip: 03753
# Output annual data for zip: 03754
# Output annual data for zip: 03755
# Output annual data for zip: 03765
# Output annual data for zip: 03766
# Output annual data for zip: 03768
# Output annual data for zip: 03770
# Output annual data for zip: 03771
# Output annual data for zip: 03773
# Output annual data for zip: 03774
# Output annual data for zip: 03777
# Output annual data for zip: 03779
# Output annual data for zip: 03780
# Output annual data for zip: 03781
# Output annual data for zip: 03782
# Output annual data for zip: 03784
# Output annual data for zip: 03785
# Output annual data for zip: 03801
# Output annual data for zip: 03809
# Output annual data for zip: 03810
# Output annual data for zip: 03811
# Output annual data for zip: 03812
# Output annual data for zip: 03813
# Output annual data for zip: 03814
# Output annual data for zip: 03816
# Output annual data for zip: 03817
# Output annual data for zip: 03818
# Output annual data for zip: 03819
# Output annual data for zip: 03820
# Output annual data for zip: 03823
# Output annual data for zip: 03824
# Output annual data for zip: 03825
# Output annual data for zip: 03826
# Output annual data for zip: 03827
# Output annual data for zip: 03830
# Output annual data for zip: 03832
# Output annual data for zip: 03833
# Output annual data for zip: 03835
# Output annual data for zip: 03836
# Output annual data for zip: 03837
# Output annual data for zip: 03838
# Output annual data for zip: 03839
# Output annual data for zip: 03840
# Output annual data for zip: 03841
# Output annual data for zip: 03842
# Output annual data for zip: 03844
# Output annual data for zip: 03845
# Output annual data for zip: 03846
# Output annual data for zip: 03847
# Output annual data for zip: 03848
# Output annual data for zip: 03849
# Output annual data for zip: 03850
# Output annual data for zip: 03851
# Output annual data for zip: 03852
# Output annual data for zip: 03853
# Output annual data for zip: 03854
# Output annual data for zip: 03855
# Output annual data for zip: 03856
# Output annual data for zip: 03857
# Output annual data for zip: 03858
# Output annual data for zip: 03860
# Output annual data for zip: 03861
# Output annual data for zip: 03862
# Output annual data for zip: 03864
# Output annual data for zip: 03865
# Output annual data for zip: 03867
# Output annual data for zip: 03868
# Output annual data for zip: 03869
# Output annual data for zip: 03870
# Output annual data for zip: 03871
# Output annual data for zip: 03872
# Output annual data for zip: 03873
# Output annual data for zip: 03874
# Output annual data for zip: 03875
# Output annual data for zip: 03878
# Output annual data for zip: 03882
# Output annual data for zip: 03883
# Output annual data for zip: 03884
# Output annual data for zip: 03885
# Output annual data for zip: 03886
# Output annual data for zip: 03887
# Output annual data for zip: 03890
# Output annual data for zip: 03894
# Output annual data for zip: 03901
# Output annual data for zip: 03902
# Output annual data for zip: 03903
# Output annual data for zip: 03904
# Output annual data for zip: 03905
# Output annual data for zip: 03906
# Output annual data for zip: 03907
# Output annual data for zip: 03908
# Output annual data for zip: 03909
# Output annual data for zip: 03910
# Output annual data for zip: 03911
# Output annual data for zip: 04001
# Output annual data for zip: 04002
# Output annual data for zip: 04003
# Output annual data for zip: 04005
# Output annual data for zip: 04006
# Output annual data for zip: 04008
# Output annual data for zip: 04009
# Output annual data for zip: 04010
# Output annual data for zip: 04011
# Output annual data for zip: 04015
# Output annual data for zip: 04017
# Output annual data for zip: 04019
# Output annual data for zip: 04020
# Output annual data for zip: 04021
# Output annual data for zip: 04022
# Output annual data for zip: 04024
# Output annual data for zip: 04027
# Output annual data for zip: 04029
# Output annual data for zip: 04030
# Output annual data for zip: 04032
# Output annual data for zip: 04037
# Output annual data for zip: 04038
# Output annual data for zip: 04039
# Output annual data for zip: 04040
# Output annual data for zip: 04041
# Output annual data for zip: 04042
# Output annual data for zip: 04043
# Output annual data for zip: 04046
# Output annual data for zip: 04047
# Output annual data for zip: 04048
# Output annual data for zip: 04049
# Output annual data for zip: 04050
# Output annual data for zip: 04051
# Output annual data for zip: 04055
# Output annual data for zip: 04056
# Output annual data for zip: 04057
# Output annual data for zip: 04061
# Output annual data for zip: 04062
# Output annual data for zip: 04063
# Output annual data for zip: 04064
# Output annual data for zip: 04066
# Output annual data for zip: 04068
# Output annual data for zip: 04069
# Output annual data for zip: 04071
# Output annual data for zip: 04072
# Output annual data for zip: 04073
# Output annual data for zip: 04074
# Output annual data for zip: 04076
# Output annual data for zip: 04079
# Output annual data for zip: 04083
# Output annual data for zip: 04084
# Output annual data for zip: 04085
# Output annual data for zip: 04086
# Output annual data for zip: 04087
# Output annual data for zip: 04088
# Output annual data for zip: 04090
# Output annual data for zip: 04091
# Output annual data for zip: 04092
# Output annual data for zip: 04093
# Output annual data for zip: 04095
# Output annual data for zip: 04096
# Output annual data for zip: 04097
# Output annual data for zip: 04101
# Output annual data for zip: 04102
# Output annual data for zip: 04103
# Output annual data for zip: 04105
# Output annual data for zip: 04106
# Output annual data for zip: 04107
# Output annual data for zip: 04108
# Output annual data for zip: 04109
# Output annual data for zip: 04110
# Output annual data for zip: 04210
# Output annual data for zip: 04216
# Output annual data for zip: 04217
# Output annual data for zip: 04219
# Output annual data for zip: 04220
# Output annual data for zip: 04221
# Output annual data for zip: 04222
# Output annual data for zip: 04224
# Output annual data for zip: 04226
# Output annual data for zip: 04227
# Output annual data for zip: 04228
# Output annual data for zip: 04231
# Output annual data for zip: 04234
# Output annual data for zip: 04236
# Output annual data for zip: 04237
# Output annual data for zip: 04238
# Output annual data for zip: 04239
# Output annual data for zip: 04240
# Output annual data for zip: 04250
# Output annual data for zip: 04252
# Output annual data for zip: 04253
# Output annual data for zip: 04254
# Output annual data for zip: 04255
# Output annual data for zip: 04256
# Output annual data for zip: 04257
# Output annual data for zip: 04258
# Output annual data for zip: 04259
# Output annual data for zip: 04260
# Output annual data for zip: 04261
# Output annual data for zip: 04263
# Output annual data for zip: 04265
# Output annual data for zip: 04267
# Output annual data for zip: 04268
# Output annual data for zip: 04270
# Output annual data for zip: 04271
# Output annual data for zip: 04274
# Output annual data for zip: 04275
# Output annual data for zip: 04276
# Output annual data for zip: 04280
# Output annual data for zip: 04281
# Output annual data for zip: 04282
# Output annual data for zip: 04284
# Output annual data for zip: 04285
# Output annual data for zip: 04286
# Output annual data for zip: 04287
# Output annual data for zip: 04289
# Output annual data for zip: 04290
# Output annual data for zip: 04292
# Output annual data for zip: 04294
# Output annual data for zip: 04330
# Output annual data for zip: 04342
# Output annual data for zip: 04343
# Output annual data for zip: 04344
# Output annual data for zip: 04345
# Output annual data for zip: 04346
# Output annual data for zip: 04347
# Output annual data for zip: 04348
# Output annual data for zip: 04349
# Output annual data for zip: 04350
# Output annual data for zip: 04351
# Output annual data for zip: 04352
# Output annual data for zip: 04353
# Output annual data for zip: 04354
# Output annual data for zip: 04355
# Output annual data for zip: 04357
# Output annual data for zip: 04358
# Output annual data for zip: 04359
# Output annual data for zip: 04360
# Output annual data for zip: 04363
# Output annual data for zip: 04364
# Output annual data for zip: 04401
# Output annual data for zip: 04406
# Output annual data for zip: 04408
# Output annual data for zip: 04410
# Output annual data for zip: 04411
# Output annual data for zip: 04412
# Output annual data for zip: 04413
# Output annual data for zip: 04414
# Output annual data for zip: 04415
# Output annual data for zip: 04416
# Output annual data for zip: 04417
# Output annual data for zip: 04418
# Output annual data for zip: 04419
# Output annual data for zip: 04421
# Output annual data for zip: 04422
# Output annual data for zip: 04424
# Output annual data for zip: 04426
# Output annual data for zip: 04427
# Output annual data for zip: 04428
# Output annual data for zip: 04429
# Output annual data for zip: 04430
# Output annual data for zip: 04431
# Output annual data for zip: 04434
# Output annual data for zip: 04435
# Output annual data for zip: 04438
# Output annual data for zip: 04441
# Output annual data for zip: 04442
# Output annual data for zip: 04443
# Output annual data for zip: 04444
# Output annual data for zip: 04448
# Output annual data for zip: 04449
# Output annual data for zip: 04450
# Output annual data for zip: 04451
# Output annual data for zip: 04453
# Output annual data for zip: 04454
# Output annual data for zip: 04455
# Output annual data for zip: 04456
# Output annual data for zip: 04457
# Output annual data for zip: 04459
# Output annual data for zip: 04460
# Output annual data for zip: 04461
# Output annual data for zip: 04462
# Output annual data for zip: 04463
# Output annual data for zip: 04464
# Output annual data for zip: 04468
# Output annual data for zip: 04469
# Output annual data for zip: 04471
# Output annual data for zip: 04472
# Output annual data for zip: 04473
# Output annual data for zip: 04474
# Output annual data for zip: 04475
# Output annual data for zip: 04476
# Output annual data for zip: 04478
# Output annual data for zip: 04479
# Output annual data for zip: 04481
# Output annual data for zip: 04485
# Output annual data for zip: 04487
# Output annual data for zip: 04488
# Output annual data for zip: 04489
# Output annual data for zip: 04490
# Output annual data for zip: 04491
# Output annual data for zip: 04492
# Output annual data for zip: 04493
# Output annual data for zip: 04495
# Output annual data for zip: 04496
# Output annual data for zip: 04497
# Output annual data for zip: 04530
# Output annual data for zip: 04535
# Output annual data for zip: 04537
# Output annual data for zip: 04538
# Output annual data for zip: 04539
# Output annual data for zip: 04541
# Output annual data for zip: 04543
# Output annual data for zip: 04544
# Output annual data for zip: 04547
# Output annual data for zip: 04548
# Output annual data for zip: 04551
# Output annual data for zip: 04553
# Output annual data for zip: 04554
# Output annual data for zip: 04555
# Output annual data for zip: 04556
# Output annual data for zip: 04558
# Output annual data for zip: 04562
# Output annual data for zip: 04563
# Output annual data for zip: 04564
# Output annual data for zip: 04568
# Output annual data for zip: 04570
# Output annual data for zip: 04571
# Output annual data for zip: 04572
# Output annual data for zip: 04573
# Output annual data for zip: 04574
# Output annual data for zip: 04575
# Output annual data for zip: 04576
# Output annual data for zip: 04578
# Output annual data for zip: 04579
# Output annual data for zip: 04605
# Output annual data for zip: 04606
# Output annual data for zip: 04607
# Output annual data for zip: 04609
# Output annual data for zip: 04611
# Output annual data for zip: 04612
# Output annual data for zip: 04613
# Output annual data for zip: 04614
# Output annual data for zip: 04616
# Output annual data for zip: 04617
# Output annual data for zip: 04619
# Output annual data for zip: 04622
# Output annual data for zip: 04623
# Output annual data for zip: 04624
# Output annual data for zip: 04625
# Output annual data for zip: 04626
# Output annual data for zip: 04627
# Output annual data for zip: 04628
# Output annual data for zip: 04629
# Output annual data for zip: 04630
# Output annual data for zip: 04631
# Output annual data for zip: 04634
# Output annual data for zip: 04635
# Output annual data for zip: 04637
# Output annual data for zip: 04640
# Output annual data for zip: 04642
# Output annual data for zip: 04643
# Output annual data for zip: 04644
# Output annual data for zip: 04645
# Output annual data for zip: 04646
# Output annual data for zip: 04648
# Output annual data for zip: 04649
# Output annual data for zip: 04650
# Output annual data for zip: 04652
# Output annual data for zip: 04653
# Output annual data for zip: 04654
# Output annual data for zip: 04655
# Output annual data for zip: 04657
# Output annual data for zip: 04658
# Output annual data for zip: 04660
# Output annual data for zip: 04662
# Output annual data for zip: 04664
# Output annual data for zip: 04666
# Output annual data for zip: 04667
# Output annual data for zip: 04668
# Output annual data for zip: 04669
# Output annual data for zip: 04671
# Output annual data for zip: 04673
# Output annual data for zip: 04674
# Output annual data for zip: 04675
# Output annual data for zip: 04676
# Output annual data for zip: 04677
# Output annual data for zip: 04679
# Output annual data for zip: 04680
# Output annual data for zip: 04681
# Output annual data for zip: 04683
# Output annual data for zip: 04684
# Output annual data for zip: 04685
# Output annual data for zip: 04686
# Output annual data for zip: 04691
# Output annual data for zip: 04693
# Output annual data for zip: 04694
# Output annual data for zip: 04730
# Output annual data for zip: 04732
# Output annual data for zip: 04733
# Output annual data for zip: 04734
# Output annual data for zip: 04735
# Output annual data for zip: 04736
# Output annual data for zip: 04739
# Output annual data for zip: 04740
# Output annual data for zip: 04741
# Output annual data for zip: 04742
# Output annual data for zip: 04743
# Output annual data for zip: 04745
# Output annual data for zip: 04746
# Output annual data for zip: 04747
# Output annual data for zip: 04750
# Output annual data for zip: 04756
# Output annual data for zip: 04757
# Output annual data for zip: 04758
# Output annual data for zip: 04760
# Output annual data for zip: 04761
# Output annual data for zip: 04762
# Output annual data for zip: 04763
# Output annual data for zip: 04764
# Output annual data for zip: 04765
# Output annual data for zip: 04766
# Output annual data for zip: 04768
# Output annual data for zip: 04769
# Output annual data for zip: 04772
# Output annual data for zip: 04773
# Output annual data for zip: 04774
# Output annual data for zip: 04776
# Output annual data for zip: 04777
# Output annual data for zip: 04779
# Output annual data for zip: 04780
# Output annual data for zip: 04781
# Output annual data for zip: 04783
# Output annual data for zip: 04785
# Output annual data for zip: 04786
# Output annual data for zip: 04787
# Output annual data for zip: 04841
# Output annual data for zip: 04843
# Output annual data for zip: 04847
# Output annual data for zip: 04848
# Output annual data for zip: 04849
# Output annual data for zip: 04851
# Output annual data for zip: 04852
# Output annual data for zip: 04853
# Output annual data for zip: 04854
# Output annual data for zip: 04855
# Output annual data for zip: 04856
# Output annual data for zip: 04858
# Output annual data for zip: 04859
# Output annual data for zip: 04860
# Output annual data for zip: 04861
# Output annual data for zip: 04862
# Output annual data for zip: 04863
# Output annual data for zip: 04864
# Output annual data for zip: 04901
# Output annual data for zip: 04910
# Output annual data for zip: 04911
# Output annual data for zip: 04912
# Output annual data for zip: 04915
# Output annual data for zip: 04917
# Output annual data for zip: 04918
# Output annual data for zip: 04920
# Output annual data for zip: 04921
# Output annual data for zip: 04922
# Output annual data for zip: 04923
# Output annual data for zip: 04924
# Output annual data for zip: 04925
# Output annual data for zip: 04926
# Output annual data for zip: 04927
# Output annual data for zip: 04928
# Output annual data for zip: 04929
# Output annual data for zip: 04930
# Output annual data for zip: 04932
# Output annual data for zip: 04933
# Output annual data for zip: 04936
# Output annual data for zip: 04937
# Output annual data for zip: 04938
# Output annual data for zip: 04939
# Output annual data for zip: 04940
# Output annual data for zip: 04941
# Output annual data for zip: 04942
# Output annual data for zip: 04943
# Output annual data for zip: 04944
# Output annual data for zip: 04945
# Output annual data for zip: 04947
# Output annual data for zip: 04949
# Output annual data for zip: 04950
# Output annual data for zip: 04951
# Output annual data for zip: 04952
# Output annual data for zip: 04953
# Output annual data for zip: 04955
# Output annual data for zip: 04956
# Output annual data for zip: 04957
# Output annual data for zip: 04958
# Output annual data for zip: 04961
# ...
# Output annual data for zip: 98673
# Output annual data for zip: 98674
# Output annual data for zip: 98675
# Output annual data for zip: 98682
# Output annual data for zip: 98683
# Output annual data for zip: 98684
# Output annual data for zip: 98685
# Output annual data for zip: 98686
# Output annual data for zip: 98801
# Output annual data for zip: 98802
# Output annual data for zip: 98811
# Output annual data for zip: 98812
# Output annual data for zip: 98813
# Output annual data for zip: 98814
# Output annual data for zip: 98815
# Output annual data for zip: 98816
# Output annual data for zip: 98817
# Output annual data for zip: 98819
# Output annual data for zip: 98821
# Output annual data for zip: 98822
# Output annual data for zip: 98823
# Output annual data for zip: 98824
# Output annual data for zip: 98826
# Output annual data for zip: 98827
# Output annual data for zip: 98828
# Output annual data for zip: 98829
# Output annual data for zip: 98830
# Output annual data for zip: 98831
# Output annual data for zip: 98832
# Output annual data for zip: 98833
# Output annual data for zip: 98834
# Output annual data for zip: 98836
# Output annual data for zip: 98837
# Output annual data for zip: 98840
# Output annual data for zip: 98841
# Output annual data for zip: 98843
# Output annual data for zip: 98844
# Output annual data for zip: 98845
# Output annual data for zip: 98846
# Output annual data for zip: 98847
# Output annual data for zip: 98848
# Output annual data for zip: 98849
# Output annual data for zip: 98850
# Output annual data for zip: 98851
# Output annual data for zip: 98852
# Output annual data for zip: 98853
# Output annual data for zip: 98855
# Output annual data for zip: 98856
# Output annual data for zip: 98857
# Output annual data for zip: 98858
# Output annual data for zip: 98859
# Output annual data for zip: 98860
# Output annual data for zip: 98862
# Output annual data for zip: 98901
# Output annual data for zip: 98902
# Output annual data for zip: 98903
# Output annual data for zip: 98908
# Output annual data for zip: 98921
# Output annual data for zip: 98922
# Output annual data for zip: 98923
# Output annual data for zip: 98925
# Output annual data for zip: 98926
# Output annual data for zip: 98929
# Output annual data for zip: 98930
# Output annual data for zip: 98932
# Output annual data for zip: 98933
# Output annual data for zip: 98934
# Output annual data for zip: 98935
# Output annual data for zip: 98936
# Output annual data for zip: 98937
# Output annual data for zip: 98938
# Output annual data for zip: 98939
# Output annual data for zip: 98940
# Output annual data for zip: 98941
# Output annual data for zip: 98942
# Output annual data for zip: 98943
# Output annual data for zip: 98944
# Output annual data for zip: 98946
# Output annual data for zip: 98947
# Output annual data for zip: 98948
# Output annual data for zip: 98950
# Output annual data for zip: 98951
# Output annual data for zip: 98952
# Output annual data for zip: 98953
# Output annual data for zip: 99001
# Output annual data for zip: 99003
# Output annual data for zip: 99004
# Output annual data for zip: 99005
# Output annual data for zip: 99006
# Output annual data for zip: 99008
# Output annual data for zip: 99009
# Output annual data for zip: 99011
# Output annual data for zip: 99012
# Output annual data for zip: 99013
# Output annual data for zip: 99016
# Output annual data for zip: 99017
# Output annual data for zip: 99018
# Output annual data for zip: 99019
# Output annual data for zip: 99020
# Output annual data for zip: 99021
# Output annual data for zip: 99022
# Output annual data for zip: 99023
# Output annual data for zip: 99025
# Output annual data for zip: 99026
# Output annual data for zip: 99027
# Output annual data for zip: 99029
# Output annual data for zip: 99030
# Output annual data for zip: 99031
# Output annual data for zip: 99032
# Output annual data for zip: 99033
# Output annual data for zip: 99034
# Output annual data for zip: 99036
# Output annual data for zip: 99037
# Output annual data for zip: 99039
# Output annual data for zip: 99040
# Output annual data for zip: 99101
# Output annual data for zip: 99102
# Output annual data for zip: 99103
# Output annual data for zip: 99105
# Output annual data for zip: 99109
# Output annual data for zip: 99110
# Output annual data for zip: 99111
# Output annual data for zip: 99113
# Output annual data for zip: 99114
# Output annual data for zip: 99115
# Output annual data for zip: 99116
# Output annual data for zip: 99117
# Output annual data for zip: 99118
# Output annual data for zip: 99119
# Output annual data for zip: 99121
# Output annual data for zip: 99122
# Output annual data for zip: 99123
# Output annual data for zip: 99124
# Output annual data for zip: 99125
# Output annual data for zip: 99126
# Output annual data for zip: 99128
# Output annual data for zip: 99129
# Output annual data for zip: 99130
# Output annual data for zip: 99131
# Output annual data for zip: 99133
# Output annual data for zip: 99134
# Output annual data for zip: 99135
# Output annual data for zip: 99136
# Output annual data for zip: 99137
# Output annual data for zip: 99138
# Output annual data for zip: 99139
# Output annual data for zip: 99140
# Output annual data for zip: 99141
# Output annual data for zip: 99143
# Output annual data for zip: 99144
# Output annual data for zip: 99146
# Output annual data for zip: 99147
# Output annual data for zip: 99148
# Output annual data for zip: 99149
# Output annual data for zip: 99150
# Output annual data for zip: 99151
# Output annual data for zip: 99152
# Output annual data for zip: 99153
# Output annual data for zip: 99154
# Output annual data for zip: 99155
# Output annual data for zip: 99156
# Output annual data for zip: 99157
# Output annual data for zip: 99158
# Output annual data for zip: 99159
# Output annual data for zip: 99160
# Output annual data for zip: 99161
# Output annual data for zip: 99163
# Output annual data for zip: 99164
# Output annual data for zip: 99166
# Output annual data for zip: 99167
# Output annual data for zip: 99169
# Output annual data for zip: 99170
# Output annual data for zip: 99171
# Output annual data for zip: 99173
# Output annual data for zip: 99174
# Output annual data for zip: 99176
# Output annual data for zip: 99179
# Output annual data for zip: 99180
# Output annual data for zip: 99181
# Output annual data for zip: 99185
# Output annual data for zip: 99201
# Output annual data for zip: 99202
# Output annual data for zip: 99203
# Output annual data for zip: 99204
# Output annual data for zip: 99205
# Output annual data for zip: 99206
# Output annual data for zip: 99207
# Output annual data for zip: 99208
# Output annual data for zip: 99212
# Output annual data for zip: 99216
# Output annual data for zip: 99217
# Output annual data for zip: 99218
# Output annual data for zip: 99223
# Output annual data for zip: 99224
# Output annual data for zip: 99301
# Output annual data for zip: 99320
# Output annual data for zip: 99321
# Output annual data for zip: 99322
# Output annual data for zip: 99323
# Output annual data for zip: 99324
# Output annual data for zip: 99326
# Output annual data for zip: 99328
# Output annual data for zip: 99329
# Output annual data for zip: 99330
# Output annual data for zip: 99333
# Output annual data for zip: 99335
# Output annual data for zip: 99336
# Output annual data for zip: 99337
# Output annual data for zip: 99338
# Output annual data for zip: 99341
# Output annual data for zip: 99343
# Output annual data for zip: 99344
# Output annual data for zip: 99345
# Output annual data for zip: 99346
# Output annual data for zip: 99347
# Output annual data for zip: 99348
# Output annual data for zip: 99349
# Output annual data for zip: 99350
# Output annual data for zip: 99352
# Output annual data for zip: 99353
# Output annual data for zip: 99354
# Output annual data for zip: 99356
# Output annual data for zip: 99357
# Output annual data for zip: 99359
# Output annual data for zip: 99360
# Output annual data for zip: 99361
# Output annual data for zip: 99362
# Output annual data for zip: 99363
# Output annual data for zip: 99371
# Output annual data for zip: 99401
# Output annual data for zip: 99402
# Output annual data for zip: 99403
# Output annual data for zip: 99501
# Output annual data for zip: 99502
# Output annual data for zip: 99503
# Output annual data for zip: 99504
# Output annual data for zip: 99505
# Output annual data for zip: 99506
# Output annual data for zip: 99507
# Output annual data for zip: 99508
# Output annual data for zip: 99510
# Output annual data for zip: 99513
# Output annual data for zip: 99515
# Output annual data for zip: 99516
# Output annual data for zip: 99517
# Output annual data for zip: 99518
# Output annual data for zip: 99519
# Output annual data for zip: 99540
# Output annual data for zip: 99546
# Output annual data for zip: 99547
# Output annual data for zip: 99548
# Output annual data for zip: 99549
# Output annual data for zip: 99550
# Output annual data for zip: 99551
# Output annual data for zip: 99552
# Output annual data for zip: 99553
# Output annual data for zip: 99554
# Output annual data for zip: 99555
# Output annual data for zip: 99556
# Output annual data for zip: 99557
# Output annual data for zip: 99558
# Output annual data for zip: 99559
# Output annual data for zip: 99561
# Output annual data for zip: 99563
# Output annual data for zip: 99564
# Output annual data for zip: 99565
# Output annual data for zip: 99566
# Output annual data for zip: 99567
# Output annual data for zip: 99568
# Output annual data for zip: 99569
# Output annual data for zip: 99571
# Output annual data for zip: 99572
# Output annual data for zip: 99573
# Output annual data for zip: 99574
# Output annual data for zip: 99575
# Output annual data for zip: 99576
# Output annual data for zip: 99577
# Output annual data for zip: 99578
# Output annual data for zip: 99579
# Output annual data for zip: 99580
# Output annual data for zip: 99581
# Output annual data for zip: 99583
# Output annual data for zip: 99585
# Output annual data for zip: 99586
# Output annual data for zip: 99587
# Output annual data for zip: 99588
# Output annual data for zip: 99589
# Output annual data for zip: 99590
# Output annual data for zip: 99591
# Output annual data for zip: 99602
# Output annual data for zip: 99603
# Output annual data for zip: 99604
# Output annual data for zip: 99605
# Output annual data for zip: 99606
# Output annual data for zip: 99607
# Output annual data for zip: 99609
# Output annual data for zip: 99610
# Output annual data for zip: 99611
# Output annual data for zip: 99612
# Output annual data for zip: 99613
# Output annual data for zip: 99614
# Output annual data for zip: 99615
# Output annual data for zip: 99620
# Output annual data for zip: 99621
# Output annual data for zip: 99622
# Output annual data for zip: 99624
# Output annual data for zip: 99625
# Output annual data for zip: 99626
# Output annual data for zip: 99627
# Output annual data for zip: 99628
# Output annual data for zip: 99630
# Output annual data for zip: 99631
# Output annual data for zip: 99632
# Output annual data for zip: 99633
# Output annual data for zip: 99634
# Output annual data for zip: 99636
# Output annual data for zip: 99637
# Output annual data for zip: 99638
# Output annual data for zip: 99639
# Output annual data for zip: 99640
# Output annual data for zip: 99641
# Output annual data for zip: 99643
# Output annual data for zip: 99644
# Output annual data for zip: 99645
# Output annual data for zip: 99647
# Output annual data for zip: 99648
# Output annual data for zip: 99649
# Output annual data for zip: 99650
# Output annual data for zip: 99651
# Output annual data for zip: 99652
# Output annual data for zip: 99653
# Output annual data for zip: 99654
# Output annual data for zip: 99655
# Output annual data for zip: 99656
# Output annual data for zip: 99657
# Output annual data for zip: 99658
# Output annual data for zip: 99659
# Output annual data for zip: 99660
# Output annual data for zip: 99661
# Output annual data for zip: 99662
# Output annual data for zip: 99663
# Output annual data for zip: 99664
# Output annual data for zip: 99665
# Output annual data for zip: 99666
# Output annual data for zip: 99667
# Output annual data for zip: 99668
# Output annual data for zip: 99669
# Output annual data for zip: 99670
# Output annual data for zip: 99671
# Output annual data for zip: 99672
# Output annual data for zip: 99674
# Output annual data for zip: 99676
# Output annual data for zip: 99677
# Output annual data for zip: 99678
# Output annual data for zip: 99679
# Output annual data for zip: 99680
# Output annual data for zip: 99681
# Output annual data for zip: 99682
# Output annual data for zip: 99683
# Output annual data for zip: 99684
# Output annual data for zip: 99685
# Output annual data for zip: 99686
# Output annual data for zip: 99688
# Output annual data for zip: 99689
# Output annual data for zip: 99690
# Output annual data for zip: 99691
# Output annual data for zip: 99692
# Output annual data for zip: 99693
# Output annual data for zip: 99694
# Output annual data for zip: 99695
# Output annual data for zip: 99701
# Output annual data for zip: 99702
# Output annual data for zip: 99703
# Output annual data for zip: 99704
# Output annual data for zip: 99705
# Output annual data for zip: 99706
# Output annual data for zip: 99709
# Output annual data for zip: 99712
# Output annual data for zip: 99714
# Output annual data for zip: 99720
# Output annual data for zip: 99721
# Output annual data for zip: 99722
# Output annual data for zip: 99723
# Output annual data for zip: 99724
# Output annual data for zip: 99726
# Output annual data for zip: 99727
# Output annual data for zip: 99729
# Output annual data for zip: 99730
# Output annual data for zip: 99732
# Output annual data for zip: 99733
# Output annual data for zip: 99734
# Output annual data for zip: 99736
# Output annual data for zip: 99737
# Output annual data for zip: 99738
# Output annual data for zip: 99739
# Output annual data for zip: 99740
# Output annual data for zip: 99741
# Output annual data for zip: 99742
# Output annual data for zip: 99743
# Output annual data for zip: 99744
# Output annual data for zip: 99745
# Output annual data for zip: 99746
# Output annual data for zip: 99747
# Output annual data for zip: 99748
# Output annual data for zip: 99749
# Output annual data for zip: 99750
# Output annual data for zip: 99751
# Output annual data for zip: 99752
# Output annual data for zip: 99753
# Output annual data for zip: 99754
# Output annual data for zip: 99755
# Output annual data for zip: 99756
# Output annual data for zip: 99757
# Output annual data for zip: 99758
# Output annual data for zip: 99759
# Output annual data for zip: 99760
# Output annual data for zip: 99761
# Output annual data for zip: 99762
# Output annual data for zip: 99763
# Output annual data for zip: 99764
# Output annual data for zip: 99765
# Output annual data for zip: 99766
# Output annual data for zip: 99767
# Output annual data for zip: 99768
# Output annual data for zip: 99769
# Output annual data for zip: 99770
# Output annual data for zip: 99771
# Output annual data for zip: 99772
# Output annual data for zip: 99773
# Output annual data for zip: 99774
# Output annual data for zip: 99775
# Output annual data for zip: 99776
# Output annual data for zip: 99777
# Output annual data for zip: 99778
# Output annual data for zip: 99780
# Output annual data for zip: 99781
# Output annual data for zip: 99782
# Output annual data for zip: 99783
# Output annual data for zip: 99784
# Output annual data for zip: 99785
# Output annual data for zip: 99786
# Output annual data for zip: 99788
# Output annual data for zip: 99789
# Output annual data for zip: 99790
# Output annual data for zip: 99791
# Output annual data for zip: 99801
# Output annual data for zip: 99820
# Output annual data for zip: 99824
# Output annual data for zip: 99825
# Output annual data for zip: 99826
# Output annual data for zip: 99827
# Output annual data for zip: 99829
# Output annual data for zip: 99830
# Output annual data for zip: 99832
# Output annual data for zip: 99833
# Output annual data for zip: 99835
# Output annual data for zip: 99836
# Output annual data for zip: 99840
# Output annual data for zip: 99841
# Output annual data for zip: 99901
# Output annual data for zip: 99903
# Output annual data for zip: 99918
# Output annual data for zip: 99919
# Output annual data for zip: 99921
# Output annual data for zip: 99922
# Output annual data for zip: 99923
# Output annual data for zip: 99925
# Output annual data for zip: 99926
# Output annual data for zip: 99927
# Output annual data for zip: 99929
