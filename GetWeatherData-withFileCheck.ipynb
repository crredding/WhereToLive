# %%
from datetime import datetime
import matplotlib.pyplot as plt
import meteostat
#https://dev.meteostat.net/python/
from meteostat import units, Stations
import pandas as pd
import numpy as np
from time import time
pd.set_option('display.max_columns', 150)
import geopy.distance
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Import Cloudy Data

# %%
cloudy_data = pd.read_csv('DataSets/Weather/zip_lat_lon_wban_cloudiness_data.csv')
cloudy_data['LAT-WBAN'] = cloudy_data['LAT']
cloudy_data['LNG-WBAN'] = cloudy_data['LNG']
cloudy_data['wban-distance-km'] = cloudy_data['wban_distance_km']
def zip_str(row):
    zip_str = str(int(row['ZIP']))
    while len(zip_str) < 5:
        zip_str = '0' + zip_str
    return zip_str
cloudy_data['zip_str'] = cloudy_data.apply(lambda row: zip_str(row), axis =1)
col_to_drop = ['Unnamed: 0', 'Jan CL_zipcode', 'Yrs_zipcode', 'closestWBAN', 
       'Jan PC_zipcode', 'Jan CD_zipcode', 'Feb CL_zipcode', 'Feb PC_zipcode',
       'Feb CD_zipcode', 'Mar CL_zipcode', 'Mar PC_zipcode', 'Mar CD_zipcode',
       'Apr CL_zipcode', 'Apr PC_zipcode', 'Apr CD_zipcode', 'May CL_zipcode',
       'May PC_zipcode', 'May CD_zipcode', 'Jun CL_zipcode', 'Jun PC_zipcode',
       'Jun CD_zipcode', 'Jul CL_zipcode', 'Jul PC_zipcode', 'Jul CD_zipcode',
       'Aug CL_zipcode', 'Aug PC_zipcode', 'Aug CD_zipcode', 'Sept CL_zipcode',
       'Sept PC_zipcode', 'Sept CD_zipcode', 'Oct CL_zipcode',
       'Oct PC_zipcode', 'Oct CD_zipcode', 'Nov CL_zipcode', 'Nov PC_zipcode',
       'Nov CD_zipcode', 'Dec CL_zipcode', 'Dec PC_zipcode', 'Dec CD_zipcode',
       'Ann  CL_zipcode', 'Ann  PC_zipcode', 'Ann  CD_zipcode',
      'State_zipcode', 'City_zipcode', 'LAT_wban', 'LNG_wban', 'LAT', 'LNG',
      'wban_distance_km', 'ZIP']
cloudy_data = cloudy_data.drop(col_to_drop, axis=1)
cloudy_data.columns = [column.split('_')[0] for column in cloudy_data.columns]

# %%
for zip_code in cloudy_data['zip']:
    # Check if file already exists in output
    if any([zip_code in file for file in listdir('DataSets/Weather/Daily/')]):
        pass
    else:
        try:
            lat = cloudy_data[cloudy_data['zip'] == zip_code]['LAT'].values[0]
            lng = cloudy_data[cloudy_data['zip'] == zip_code]['LNG'].values[0]

            # wban_zip = ziplatlonwban[ziplatlonwban['zip_str'] == zip_code]
            #Create point for specfied zip_code
            location = meteostat.Point(lat, lng)
            #Set time period
            start = datetime(2019, 1, 1)
            end = datetime(2020, 1, 1)

            start_time = time()

            #Get monthly data
            data = meteostat.Hourly(location, start, end)
            data = data.convert(units.imperial)
            data = data.fetch()

            #Weather condition codes
            # https://dev.meteostat.net/formats.html#weather-condition-codes
            # data['sunny'] = data['coco'] < 3
            # data['rainy'] = (data['coco'] > 6) | (data['prcp'] > 0)

            #Scoping to afternoon data for dwpt calculation
            afternoon = data[(data.index.hour > 11) & (data.index.hour < 19)]
            afternoon_rhum = afternoon.groupby([afternoon.index.month, afternoon.index.day]).mean()['rhum']
            afternoon_rhum.index = afternoon_rhum.index.set_names(['Month', 'Day'])
            afternoon_rhum = afternoon_rhum.reset_index()
            afternoon_rhum_mthly = pd.DataFrame(afternoon_rhum.groupby('Month').mean()['rhum'])
            afternoon_rhum_mthly.columns = ['mthly_afternoon_rhum']

            grouped_by_day = data.groupby([data.index.month, 
                                           data.index.day]).agg({'temp' : ['mean', 'min', 'max', 'count'], 
                                                                            'rhum' : ['mean', 'min', 'max'], 
                                                                            'prcp' : ['sum', 'min', 'count']})
            #                                                                 'rainy' : np.max,
            #                                                                 'sunny' : np.max})

            grouped_by_day.index = grouped_by_day.index.set_names(['Month', 'Day'])
            grouped_by_day = grouped_by_day.reset_index()
            grouped_by_day.columns = ['month', 'day', 'tempmean', 'tempmin', 'tempmax', 'tempcount', 'rhummean', 'rhummin', 'rhummax', 'prcpsum', 'prcpmin', 'prcpcount']#, 'rainymax', 'sunnymax']
            grouped_by_day['over90'] = grouped_by_day['tempmax'] > 90

            grouped_by_month = grouped_by_day.groupby('month').agg({'tempmean' : 'mean',
                                                                   'tempmin' : 'mean',
                                                                   'tempmax' : 'mean',
                                                                   'tempcount' : 'sum',
                                                                   'rhummean' : 'mean',
                                                                   'rhummin' : 'mean',
                                                                   'rhummax' : 'mean',
                                                                   'prcpsum' : 'sum',
                                                                   'prcpmin' : 'mean',
                                                                    'prcpcount' : 'sum',
            #                                                        'rainymax' : 'sum',
            #                                                         'sunnymax' : 'sum',
                                                                    'over90' : 'sum'
                                                                   })

            season_dict = {1:'winter',
                          2: 'winter',
                          3: 'spring',
                          4: 'spring',
                          5: 'spring',
                          6: 'summer',
                          7: 'summer',
                          8: 'summer',
                          9: 'fall',
                          10:'fall',
                          11:'fall',
                          12:'winter'}

            grouped_by_month['season'] = grouped_by_month.index.map(season_dict)

            grouped_by_month = grouped_by_month.merge(afternoon_rhum_mthly, left_index=True, right_index=True, how='left')

            #calculating temp-humidity index (High is good)
            thi_bins = [-1, 75, 85, 95, 105, 1000]
            grouped_by_month['THI'] = grouped_by_month['tempmean'] - 0.55 * (1 - grouped_by_month['mthly_afternoon_rhum']/100) * (grouped_by_month['tempmean'] - 58)
            grouped_by_month['THI_score'] = pd.cut(grouped_by_month['THI'], thi_bins, labels = [len(thi_bins) - 2 - i for i in range(0, len(thi_bins) - 1)]).astype(int)

            #calculating temp_min index (High is good)
            temp_min_bins = [-1, 15, 25, 35, 45, 1000]
            grouped_by_month['tempmin_score'] = pd.cut(grouped_by_month['tempmin'], temp_min_bins, labels = [i for i in range(0, len(temp_min_bins) - 1)]).astype(int)

            #calculating over90 index (High is good)
            over90_bins = [-1, 3, 6, 9, 12, 15, 20, 1000]
            grouped_by_month['over90_score'] = pd.cut(grouped_by_month['over90'], over90_bins, labels = [len(thi_bins) - i for i in range(0, len(over90_bins) - 1)]).astype(int)

            #calculating rainy index (High is good)
            # rainy_bins = [-1, 3, 6, 10, 15, 20, 25, 1000]
            # grouped_by_month['rainy_score'] = pd.cut(grouped_by_month['rainymax'], rainy_bins, labels = [len(rainy_bins) - 2 - i for i in range(0, len(rainy_bins) - 1)]).astype(int)

            #calculating total rain index (High is good)
            # Not sure if we should include this one...
            rainy_sum_bins = [0.00001, 1, 2, 3, 4, 5, 6, 1000]
            grouped_by_month['rainy_sum_score'] = pd.cut(grouped_by_month['prcpsum'], rainy_sum_bins, labels = [len(rainy_sum_bins) - 2 - i for i in range(0, len(rainy_sum_bins) - 1)])
            # Filling months without rain with slightly penalized score as no one likes a complete desert
            grouped_by_month['rainy_sum_score'] = grouped_by_month['rainy_sum_score'].fillna(len(rainy_sum_bins) - 3).astype(int)

            #Adding in cloudy data
            cloud_score_bins = [0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 70]
            CL_columns = cloudy_data.columns[['CL' in x for x in cloudy_data.columns]]
            PC_columns = cloudy_data.columns[['PC' in x for x in cloudy_data.columns]]
            CD_columns = cloudy_data.columns[['CD' in x for x in cloudy_data.columns]]

            cloudiness_temp = cloudy_data[cloudy_data['zip'] == zip_code][CL_columns].T.reset_index().iloc[:12]
            cloudiness_temp['PC_days'] = cloudy_data[cloudy_data['zip'] == zip_code][PC_columns].T.reset_index().iloc[:12].iloc[:,1:].values
            cloudiness_temp['CD_days'] = cloudy_data[cloudy_data['zip'] == zip_code][CD_columns].T.reset_index().iloc[:12].iloc[:,1:].values
            cloudiness_temp = cloudiness_temp.iloc[:,1:]
            cloudiness_temp.index = [x+1 for x in range(12)]
            cloudiness_temp.columns = ['CL_days', 'PC_days', 'CD_days']
            #Creating cloud score
            cloudiness_temp['CloudScore'] = cloudiness_temp['CL_days'] * 2 + cloudiness_temp['PC_days']
            cloudiness_temp['cloud_score_binned'] = pd.cut(cloudiness_temp['CloudScore'], cloud_score_bins, labels = [i for i in range(0, len(cloud_score_bins) - 1)]).astype(int)

            grouped_by_month = grouped_by_month.merge(cloudiness_temp, how='left', left_index=True, right_index=True)

            # #Adding in sunny data
            # sunny_bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 101]
            # sunny_temp = sunny_perc[sunny_perc['zip_str'] == zip_code].T.reset_index().iloc[:12]
            # sunny_temp = sunny_temp.iloc[:,1:].astype(int)
            # sunny_temp.index = [x+1 for x in range(12)]
            # sunny_temp.columns = ['Sunny_perc']
            # sunny_temp['sunny_score_binned'] = pd.cut(sunny_temp['Sunny_perc'], sunny_bins, labels = [i for i in range(0, len(sunny_bins) - 1)]).astype(int)

            # grouped_by_month = grouped_by_month.merge(sunny_temp, how='left', left_index=True, right_index=True)

            #Calculating weather index
            thi_weight = 30
            mintemp_weight = 5
            over90_weight = 20
            rainy_sum_weight = 5
            cloud_score_weight = 40
            # sunny_perc_weight = 20
            # rainy_day_weight = 5

            max_thi_score = len(thi_bins) - 2
            max_temp_min_score = len(temp_min_bins) - 2
            max_over_90_score = len(over90_bins) - 2
            max_rainy_sum_score = len(rainy_sum_bins) - 2
            max_cloud_score = len(cloud_score_bins) - 2
            # max_sunny_score = len(sunny_bins) - 2
            # max_rainy_score = len(rainy_bins) - 2

            grouped_by_month['WeatherIndex'] = (grouped_by_month['THI_score'] / max_thi_score * thi_weight) \
                                               + (grouped_by_month['tempmin_score'] / max_temp_min_score * mintemp_weight) \
                                               + (grouped_by_month['over90_score'] / max_over_90_score * over90_weight) \
                                               + (grouped_by_month['rainy_sum_score'] / max_rainy_sum_score * rainy_sum_weight) \
                                               + (grouped_by_month['cloud_score_binned'] / max_cloud_score * cloud_score_weight) \
            #                                    + (grouped_by_month['sunny_score_binned'] / max_sunny_score * sunny_perc_weight)
            #                                    + (grouped_by_month['rainy_score'] / max_rainy_score * rainy_day_weight) \


            #Aggregating by season
            grouped_by_season = grouped_by_month.groupby('season').agg({'tempmean' : 'mean',
                                                                    'tempmin' : 'mean',
                                                                    'tempmax' : 'mean',
                                                                    'tempcount' : 'sum',
                                                                    'rhummean' : 'mean',
                                                                    'rhummin' : 'mean',
                                                                    'rhummax' : 'mean',
                                                                    'prcpsum' : 'sum',
                                                                    'prcpmin' : 'mean',
                                                                    'prcpcount' : 'sum',
            #                                                         'rainymax' : 'sum',
            #                                                         'sunnymax' : 'sum',
                                                                    'over90' : 'sum',
                                                                    'mthly_afternoon_rhum' : 'mean',
                                                                    'THI' : 'mean',
                                                                    'THI_score' : 'mean',
                                                                    'tempmin_score' : 'mean',
                                                                    'over90_score' : 'mean', 
            #                                                         'rainy_score' : 'mean',
                                                                    'rainy_sum_score' : 'mean',
                                                                    'CL_days' : 'sum',
                                                                    'PC_days' : 'sum',
                                                                    'CD_days' : 'sum',
                                                                    'cloud_score_binned' : 'mean',
                                                                    'WeatherIndex' : 'mean'
                                                                   })
            grouped_by_day.to_csv('DataSets/Weather/Daily/{}_2019daily.csv'.format(zip_code))
            grouped_by_month.to_csv('DataSets/Weather/Monthly/{}_2019monthly.csv'.format(zip_code))
            grouped_by_season.to_csv('DataSets/Weather/Seasonal/{}_2019seasonal.csv'.format(zip_code))

            end_time = time()
            print('Output data for zip: {} in {} ms'.format(zip_code, round(end_time - start_time, 2)))
        except:
            print('BREAK! Unable to output data for zip: {}'.format(zip_code))
            pass
# Out:
# BREAK! Unable to output data for zip: 00601
# BREAK! Unable to output data for zip: 00602
# BREAK! Unable to output data for zip: 00603
# BREAK! Unable to output data for zip: 00606
# BREAK! Unable to output data for zip: 00610
# BREAK! Unable to output data for zip: 00612
# BREAK! Unable to output data for zip: 00616
# BREAK! Unable to output data for zip: 00617
# BREAK! Unable to output data for zip: 00622
# BREAK! Unable to output data for zip: 00623
# BREAK! Unable to output data for zip: 00624
# BREAK! Unable to output data for zip: 00627
# BREAK! Unable to output data for zip: 00631
# BREAK! Unable to output data for zip: 00637
# BREAK! Unable to output data for zip: 00638
# BREAK! Unable to output data for zip: 00641
# BREAK! Unable to output data for zip: 00647
# BREAK! Unable to output data for zip: 00650
# BREAK! Unable to output data for zip: 12066
# BREAK! Unable to output data for zip: 12068
# BREAK! Unable to output data for zip: 12071
# BREAK! Unable to output data for zip: 12072
# BREAK! Unable to output data for zip: 12076
# BREAK! Unable to output data for zip: 12078
# BREAK! Unable to output data for zip: 12083
# BREAK! Unable to output data for zip: 12087
# BREAK! Unable to output data for zip: 12092
# BREAK! Unable to output data for zip: 12093
# BREAK! Unable to output data for zip: 12095
# BREAK! Unable to output data for zip: 12106
# BREAK! Unable to output data for zip: 12108
# BREAK! Unable to output data for zip: 12116
# BREAK! Unable to output data for zip: 12117
# BREAK! Unable to output data for zip: 12120
# BREAK! Unable to output data for zip: 12122
# BREAK! Unable to output data for zip: 12124
# BREAK! Unable to output data for zip: 12131
# BREAK! Unable to output data for zip: 12134
# BREAK! Unable to output data for zip: 12139
# BREAK! Unable to output data for zip: 12143
# BREAK! Unable to output data for zip: 12147
# BREAK! Unable to output data for zip: 12149
# BREAK! Unable to output data for zip: 12155
# BREAK! Unable to output data for zip: 12156
# BREAK! Unable to output data for zip: 12157
# BREAK! Unable to output data for zip: 12158
# BREAK! Unable to output data for zip: 12160
# BREAK! Unable to output data for zip: 12161
# BREAK! Unable to output data for zip: 12164
# BREAK! Unable to output data for zip: 12166
# BREAK! Unable to output data for zip: 12167
# BREAK! Unable to output data for zip: 12172
# BREAK! Unable to output data for zip: 12173
# BREAK! Unable to output data for zip: 12174
# BREAK! Unable to output data for zip: 12175
# BREAK! Unable to output data for zip: 12176
# BREAK! Unable to output data for zip: 12187
# BREAK! Unable to output data for zip: 12190
# BREAK! Unable to output data for zip: 12192
# BREAK! Unable to output data for zip: 12193
# BREAK! Unable to output data for zip: 12194
# BREAK! Unable to output data for zip: 12196
# BREAK! Unable to output data for zip: 12197
# BREAK! Unable to output data for zip: 12401
# BREAK! Unable to output data for zip: 12405
# BREAK! Unable to output data for zip: 12406
# BREAK! Unable to output data for zip: 12407
# BREAK! Unable to output data for zip: 12409
# BREAK! Unable to output data for zip: 12410
# BREAK! Unable to output data for zip: 12412
# BREAK! Unable to output data for zip: 12413
# BREAK! Unable to output data for zip: 12414
# BREAK! Unable to output data for zip: 12416
# BREAK! Unable to output data for zip: 12418
# BREAK! Unable to output data for zip: 12421
# BREAK! Unable to output data for zip: 12422
# BREAK! Unable to output data for zip: 12423
# BREAK! Unable to output data for zip: 12424
# BREAK! Unable to output data for zip: 12427
# BREAK! Unable to output data for zip: 12430
# BREAK! Unable to output data for zip: 12431
# BREAK! Unable to output data for zip: 12432
# BREAK! Unable to output data for zip: 12433
# BREAK! Unable to output data for zip: 12434
# BREAK! Unable to output data for zip: 12436
# BREAK! Unable to output data for zip: 12438
# BREAK! Unable to output data for zip: 12439
# BREAK! Unable to output data for zip: 12441
# BREAK! Unable to output data for zip: 12442
# BREAK! Unable to output data for zip: 12443
# BREAK! Unable to output data for zip: 12444
# BREAK! Unable to output data for zip: 12448
# BREAK! Unable to output data for zip: 12449
# BREAK! Unable to output data for zip: 12450
# BREAK! Unable to output data for zip: 12451
# BREAK! Unable to output data for zip: 12452
# BREAK! Unable to output data for zip: 12453
# BREAK! Unable to output data for zip: 12454
# BREAK! Unable to output data for zip: 12455
# BREAK! Unable to output data for zip: 12456
# BREAK! Unable to output data for zip: 12457
# BREAK! Unable to output data for zip: 12459
# BREAK! Unable to output data for zip: 12460
# BREAK! Unable to output data for zip: 12461
# BREAK! Unable to output data for zip: 12463
# BREAK! Unable to output data for zip: 12464
# BREAK! Unable to output data for zip: 12465
# BREAK! Unable to output data for zip: 12468
# BREAK! Unable to output data for zip: 12469
# BREAK! Unable to output data for zip: 12470
# BREAK! Unable to output data for zip: 12473
# BREAK! Unable to output data for zip: 12474
# BREAK! Unable to output data for zip: 12475
# BREAK! Unable to output data for zip: 12477
# BREAK! Unable to output data for zip: 12480
# BREAK! Unable to output data for zip: 12481
# BREAK! Unable to output data for zip: 12482
# BREAK! Unable to output data for zip: 12484
# BREAK! Unable to output data for zip: 12485
# BREAK! Unable to output data for zip: 12490
# BREAK! Unable to output data for zip: 12491
# BREAK! Unable to output data for zip: 12492
# BREAK! Unable to output data for zip: 12494
# BREAK! Unable to output data for zip: 12495
# BREAK! Unable to output data for zip: 12496
# BREAK! Unable to output data for zip: 12498
# BREAK! Unable to output data for zip: 12501
# BREAK! Unable to output data for zip: 12502
# BREAK! Unable to output data for zip: 12503
# BREAK! Unable to output data for zip: 12504
# BREAK! Unable to output data for zip: 12507
# BREAK! Unable to output data for zip: 12513
# BREAK! Unable to output data for zip: 12516
# BREAK! Unable to output data for zip: 12517
# BREAK! Unable to output data for zip: 12521
# BREAK! Unable to output data for zip: 12523
# BREAK! Unable to output data for zip: 12526
# BREAK! Unable to output data for zip: 12530
# BREAK! Unable to output data for zip: 12534
# BREAK! Unable to output data for zip: 12546
# BREAK! Unable to output data for zip: 12565
# BREAK! Unable to output data for zip: 12567
# BREAK! Unable to output data for zip: 12571
# BREAK! Unable to output data for zip: 12583
# BREAK! Unable to output data for zip: 12725
# BREAK! Unable to output data for zip: 12740
# BREAK! Unable to output data for zip: 12808
# BREAK! Unable to output data for zip: 12811
# BREAK! Unable to output data for zip: 12812
# BREAK! Unable to output data for zip: 12815
# BREAK! Unable to output data for zip: 12816
# BREAK! Unable to output data for zip: 12817
# BREAK! Unable to output data for zip: 12836
# BREAK! Unable to output data for zip: 12842
# BREAK! Unable to output data for zip: 12843
# BREAK! Unable to output data for zip: 12847
# BREAK! Unable to output data for zip: 12851
# BREAK! Unable to output data for zip: 12852
# BREAK! Unable to output data for zip: 12853
# BREAK! Unable to output data for zip: 12855
# BREAK! Unable to output data for zip: 12856
# BREAK! Unable to output data for zip: 12857
# BREAK! Unable to output data for zip: 12858
# BREAK! Unable to output data for zip: 12860
# BREAK! Unable to output data for zip: 12861
# BREAK! Unable to output data for zip: 12862
# BREAK! Unable to output data for zip: 12864
# BREAK! Unable to output data for zip: 12870
# BREAK! Unable to output data for zip: 12872
# BREAK! Unable to output data for zip: 12874
# BREAK! Unable to output data for zip: 12883
# BREAK! Unable to output data for zip: 12886
# BREAK! Unable to output data for zip: 12901
# BREAK! Unable to output data for zip: 12910
# BREAK! Unable to output data for zip: 12912
# BREAK! Unable to output data for zip: 12914
# BREAK! Unable to output data for zip: 12916
# BREAK! Unable to output data for zip: 12918
# BREAK! Unable to output data for zip: 12922
# BREAK! Unable to output data for zip: 12926
# BREAK! Unable to output data for zip: 12927
# BREAK! Unable to output data for zip: 12928
# BREAK! Unable to output data for zip: 12929
# BREAK! Unable to output data for zip: 12932
# BREAK! Unable to output data for zip: 12934
# BREAK! Unable to output data for zip: 12935
# BREAK! Unable to output data for zip: 12937
# BREAK! Unable to output data for zip: 12941
# BREAK! Unable to output data for zip: 12943
# BREAK! Unable to output data for zip: 12950
# BREAK! Unable to output data for zip: 12952
# BREAK! Unable to output data for zip: 12953
# BREAK! Unable to output data for zip: 12955
# BREAK! Unable to output data for zip: 12956
# BREAK! Unable to output data for zip: 12957
# BREAK! Unable to output data for zip: 12960
# BREAK! Unable to output data for zip: 12961
# BREAK! Unable to output data for zip: 12962
# BREAK! Unable to output data for zip: 12964
# BREAK! Unable to output data for zip: 12966
# BREAK! Unable to output data for zip: 12969
# BREAK! Unable to output data for zip: 12974
# BREAK! Unable to output data for zip: 12978
# BREAK! Unable to output data for zip: 12981
# BREAK! Unable to output data for zip: 12985
# BREAK! Unable to output data for zip: 12987
# BREAK! Unable to output data for zip: 12992
# BREAK! Unable to output data for zip: 12993
# BREAK! Unable to output data for zip: 12998
# BREAK! Unable to output data for zip: 13021
# BREAK! Unable to output data for zip: 13024
# BREAK! Unable to output data for zip: 13034
# BREAK! Unable to output data for zip: 13040
# BREAK! Unable to output data for zip: 13052
# BREAK! Unable to output data for zip: 13072
# BREAK! Unable to output data for zip: 13083
# BREAK! Unable to output data for zip: 13117
# BREAK! Unable to output data for zip: 13122
# BREAK! Unable to output data for zip: 13124
# BREAK! Unable to output data for zip: 13136
# BREAK! Unable to output data for zip: 13140
# BREAK! Unable to output data for zip: 13141
# BREAK! Unable to output data for zip: 13144
# BREAK! Unable to output data for zip: 13145
# BREAK! Unable to output data for zip: 13146
# BREAK! Unable to output data for zip: 13148
# BREAK! Unable to output data for zip: 13155
# BREAK! Unable to output data for zip: 13158
# BREAK! Unable to output data for zip: 13160
# BREAK! Unable to output data for zip: 13301
# BREAK! Unable to output data for zip: 13302
# BREAK! Unable to output data for zip: 13304
# BREAK! Unable to output data for zip: 13309
# BREAK! Unable to output data for zip: 13312
# BREAK! Unable to output data for zip: 13313
# BREAK! Unable to output data for zip: 13314
# BREAK! Unable to output data for zip: 13315
# BREAK! Unable to output data for zip: 13317
# BREAK! Unable to output data for zip: 13318
# BREAK! Unable to output data for zip: 13320
# BREAK! Unable to output data for zip: 13322
# BREAK! Unable to output data for zip: 13324
# BREAK! Unable to output data for zip: 13325
# BREAK! Unable to output data for zip: 13326
# BREAK! Unable to output data for zip: 13327
# BREAK! Unable to output data for zip: 14489
# BREAK! Unable to output data for zip: 14504
# BREAK! Unable to output data for zip: 14505
# BREAK! Unable to output data for zip: 14513
# BREAK! Unable to output data for zip: 14516
# BREAK! Unable to output data for zip: 14522
# BREAK! Unable to output data for zip: 14525
# BREAK! Unable to output data for zip: 14532
# BREAK! Unable to output data for zip: 14537
# BREAK! Unable to output data for zip: 14542
# BREAK! Unable to output data for zip: 14548
# BREAK! Unable to output data for zip: 14551
# BREAK! Unable to output data for zip: 14555
# BREAK! Unable to output data for zip: 14569
# BREAK! Unable to output data for zip: 14571
# BREAK! Unable to output data for zip: 14589
# BREAK! Unable to output data for zip: 14590
# BREAK! Unable to output data for zip: 14591
# BREAK! Unable to output data for zip: 14719
# BREAK! Unable to output data for zip: 14724
# BREAK! Unable to output data for zip: 14729
# BREAK! Unable to output data for zip: 14736
# BREAK! Unable to output data for zip: 14755
# BREAK! Unable to output data for zip: 14775
# BREAK! Unable to output data for zip: 14810
# BREAK! Unable to output data for zip: 14819
# BREAK! Unable to output data for zip: 14820
# BREAK! Unable to output data for zip: 14823
# BREAK! Unable to output data for zip: 14855
# BREAK! Unable to output data for zip: 14856
# BREAK! Unable to output data for zip: 14885
# BREAK! Unable to output data for zip: 14898
# BREAK! Unable to output data for zip: 15012
# BREAK! Unable to output data for zip: 15033
# BREAK! Unable to output data for zip: 15043
# BREAK! Unable to output data for zip: 15052
# BREAK! Unable to output data for zip: 15059
# BREAK! Unable to output data for zip: 15062
# BREAK! Unable to output data for zip: 15072
# BREAK! Unable to output data for zip: 15087
# BREAK! Unable to output data for zip: 15310
# BREAK! Unable to output data for zip: 15341
# BREAK! Unable to output data for zip: 15352
# BREAK! Unable to output data for zip: 15411
# BREAK! Unable to output data for zip: 15412
# BREAK! Unable to output data for zip: 15413
# BREAK! Unable to output data for zip: 15419
# BREAK! Unable to output data for zip: 15420
# BREAK! Unable to output data for zip: 15421
# BREAK! Unable to output data for zip: 15422
# BREAK! Unable to output data for zip: 15424
# BREAK! Unable to output data for zip: 15431
# BREAK! Unable to output data for zip: 15432
# BREAK! Unable to output data for zip: 15438
# BREAK! Unable to output data for zip: 15442
# BREAK! Unable to output data for zip: 15444
# BREAK! Unable to output data for zip: 15449
# BREAK! Unable to output data for zip: 15455
# BREAK! Unable to output data for zip: 15456
# BREAK! Unable to output data for zip: 15459
# BREAK! Unable to output data for zip: 15463
# BREAK! Unable to output data for zip: 15464
# BREAK! Unable to output data for zip: 15470
# BREAK! Unable to output data for zip: 15472
# BREAK! Unable to output data for zip: 15473
# BREAK! Unable to output data for zip: 15477
# BREAK! Unable to output data for zip: 15480
# BREAK! Unable to output data for zip: 15482
# BREAK! Unable to output data for zip: 15483
# BREAK! Unable to output data for zip: 15486
# BREAK! Unable to output data for zip: 15489
# BREAK! Unable to output data for zip: 15501
# BREAK! Unable to output data for zip: 15510
# BREAK! Unable to output data for zip: 15522
# BREAK! Unable to output data for zip: 15530
# BREAK! Unable to output data for zip: 16912
# BREAK! Unable to output data for zip: 16914
# BREAK! Unable to output data for zip: 16915
# BREAK! Unable to output data for zip: 16917
# BREAK! Unable to output data for zip: 16920
# BREAK! Unable to output data for zip: 16921
# BREAK! Unable to output data for zip: 16922
# BREAK! Unable to output data for zip: 16926
# BREAK! Unable to output data for zip: 16928
# BREAK! Unable to output data for zip: 16930
# BREAK! Unable to output data for zip: 16932
# BREAK! Unable to output data for zip: 16933
# BREAK! Unable to output data for zip: 16935
# BREAK! Unable to output data for zip: 16938
# BREAK! Unable to output data for zip: 16939
# BREAK! Unable to output data for zip: 16942
# BREAK! Unable to output data for zip: 16943
# BREAK! Unable to output data for zip: 16947
# BREAK! Unable to output data for zip: 16950
# BREAK! Unable to output data for zip: 17006
# BREAK! Unable to output data for zip: 17021
# BREAK! Unable to output data for zip: 17024
# BREAK! Unable to output data for zip: 17040
# BREAK! Unable to output data for zip: 17047
# BREAK! Unable to output data for zip: 17062
# BREAK! Unable to output data for zip: 17066
# BREAK! Unable to output data for zip: 17068
# BREAK! Unable to output data for zip: 17071
# BREAK! Unable to output data for zip: 17074
# BREAK! Unable to output data for zip: 17075
# BREAK! Unable to output data for zip: 17081
# BREAK! Unable to output data for zip: 17094
# BREAK! Unable to output data for zip: 17210
# BREAK! Unable to output data for zip: 17213
# BREAK! Unable to output data for zip: 17215
# BREAK! Unable to output data for zip: 17217
# BREAK! Unable to output data for zip: 17219
# BREAK! Unable to output data for zip: 17220
# BREAK! Unable to output data for zip: 17221
# BREAK! Unable to output data for zip: 17223
# BREAK! Unable to output data for zip: 17228
# BREAK! Unable to output data for zip: 17229
# BREAK! Unable to output data for zip: 17233
# BREAK! Unable to output data for zip: 17238
# BREAK! Unable to output data for zip: 17239
# BREAK! Unable to output data for zip: 17240
# BREAK! Unable to output data for zip: 17241
# BREAK! Unable to output data for zip: 17243
# BREAK! Unable to output data for zip: 17244
# BREAK! Unable to output data for zip: 17246
# BREAK! Unable to output data for zip: 17249
# BREAK! Unable to output data for zip: 17251
# BREAK! Unable to output data for zip: 17255
# BREAK! Unable to output data for zip: 17257
# BREAK! Unable to output data for zip: 17260
# BREAK! Unable to output data for zip: 17262
# BREAK! Unable to output data for zip: 17265
# BREAK! Unable to output data for zip: 17266
# BREAK! Unable to output data for zip: 17267
# BREAK! Unable to output data for zip: 17271
# BREAK! Unable to output data for zip: 17302
# BREAK! Unable to output data for zip: 17304
# BREAK! Unable to output data for zip: 17306
# BREAK! Unable to output data for zip: 17307
# BREAK! Unable to output data for zip: 17313
# BREAK! Unable to output data for zip: 17314
# BREAK! Unable to output data for zip: 17322
# BREAK! Unable to output data for zip: 17324
# BREAK! Unable to output data for zip: 17356
# BREAK! Unable to output data for zip: 17360
# BREAK! Unable to output data for zip: 17518
# BREAK! Unable to output data for zip: 17563
# BREAK! Unable to output data for zip: 17723
# BREAK! Unable to output data for zip: 17724
# BREAK! Unable to output data for zip: 17727
# BREAK! Unable to output data for zip: 18245
# BREAK! Unable to output data for zip: 18246
# BREAK! Unable to output data for zip: 18248
# BREAK! Unable to output data for zip: 18249
# BREAK! Unable to output data for zip: 18250
# BREAK! Unable to output data for zip: 18251
# BREAK! Unable to output data for zip: 18252
# BREAK! Unable to output data for zip: 18254
# BREAK! Unable to output data for zip: 18255
# BREAK! Unable to output data for zip: 18256
# BREAK! Unable to output data for zip: 18403
# BREAK! Unable to output data for zip: 18407
# BREAK! Unable to output data for zip: 18411
# BREAK! Unable to output data for zip: 18413
# BREAK! Unable to output data for zip: 18414
# BREAK! Unable to output data for zip: 18417
# BREAK! Unable to output data for zip: 18419
# BREAK! Unable to output data for zip: 18420
# BREAK! Unable to output data for zip: 18421
# BREAK! Unable to output data for zip: 18430
# BREAK! Unable to output data for zip: 18431
# BREAK! Unable to output data for zip: 18433
# BREAK! Unable to output data for zip: 18434
# BREAK! Unable to output data for zip: 18437
# BREAK! Unable to output data for zip: 18439
# BREAK! Unable to output data for zip: 18441
# BREAK! Unable to output data for zip: 18446
# BREAK! Unable to output data for zip: 18447
# BREAK! Unable to output data for zip: 18452
# BREAK! Unable to output data for zip: 18453
# BREAK! Unable to output data for zip: 18454
# BREAK! Unable to output data for zip: 18455
# BREAK! Unable to output data for zip: 18456
# BREAK! Unable to output data for zip: 18459
# BREAK! Unable to output data for zip: 18462
# BREAK! Unable to output data for zip: 18465
# BREAK! Unable to output data for zip: 18470
# BREAK! Unable to output data for zip: 18471
# BREAK! Unable to output data for zip: 18472
# BREAK! Unable to output data for zip: 18503
# BREAK! Unable to output data for zip: 18504
# BREAK! Unable to output data for zip: 18505
# BREAK! Unable to output data for zip: 18507
# BREAK! Unable to output data for zip: 18508
# BREAK! Unable to output data for zip: 18509
# BREAK! Unable to output data for zip: 18510
# BREAK! Unable to output data for zip: 18512
# BREAK! Unable to output data for zip: 18517
# BREAK! Unable to output data for zip: 18518
# BREAK! Unable to output data for zip: 18519
# BREAK! Unable to output data for zip: 18603
# BREAK! Unable to output data for zip: 18612
# BREAK! Unable to output data for zip: 18614
# BREAK! Unable to output data for zip: 18615
# BREAK! Unable to output data for zip: 18616
# BREAK! Unable to output data for zip: 18617
# BREAK! Unable to output data for zip: 18618
# BREAK! Unable to output data for zip: 18621
# BREAK! Unable to output data for zip: 18622
# BREAK! Unable to output data for zip: 18623
# BREAK! Unable to output data for zip: 18625
# BREAK! Unable to output data for zip: 18626
# BREAK! Unable to output data for zip: 18628
# BREAK! Unable to output data for zip: 18629
# BREAK! Unable to output data for zip: 18630
# BREAK! Unable to output data for zip: 18631
# BREAK! Unable to output data for zip: 18632
# BREAK! Unable to output data for zip: 18634
# BREAK! Unable to output data for zip: 18635
# BREAK! Unable to output data for zip: 18636
# BREAK! Unable to output data for zip: 18640
# BREAK! Unable to output data for zip: 18641
# BREAK! Unable to output data for zip: 18642
# BREAK! Unable to output data for zip: 18643
# BREAK! Unable to output data for zip: 18644
# BREAK! Unable to output data for zip: 18651
# BREAK! Unable to output data for zip: 18653
# BREAK! Unable to output data for zip: 18655
# BREAK! Unable to output data for zip: 18656
# BREAK! Unable to output data for zip: 18657
# BREAK! Unable to output data for zip: 18660
# BREAK! Unable to output data for zip: 18701
# BREAK! Unable to output data for zip: 18704
# BREAK! Unable to output data for zip: 18705
# BREAK! Unable to output data for zip: 18706
# BREAK! Unable to output data for zip: 18707
# BREAK! Unable to output data for zip: 18708
# BREAK! Unable to output data for zip: 18709
# BREAK! Unable to output data for zip: 18801
# BREAK! Unable to output data for zip: 18810
# ...
# BREAK! Unable to output data for zip: 97813
# BREAK! Unable to output data for zip: 97817
# BREAK! Unable to output data for zip: 97818
# BREAK! Unable to output data for zip: 97819
# BREAK! Unable to output data for zip: 97820
# BREAK! Unable to output data for zip: 97823
# BREAK! Unable to output data for zip: 97825
# BREAK! Unable to output data for zip: 97828
# BREAK! Unable to output data for zip: 97830
# BREAK! Unable to output data for zip: 97834
# BREAK! Unable to output data for zip: 97835
# BREAK! Unable to output data for zip: 97836
# BREAK! Unable to output data for zip: 97837
# BREAK! Unable to output data for zip: 97839
# BREAK! Unable to output data for zip: 97840
# BREAK! Unable to output data for zip: 97842
# BREAK! Unable to output data for zip: 97843
# BREAK! Unable to output data for zip: 97846
# BREAK! Unable to output data for zip: 97848
# BREAK! Unable to output data for zip: 97856
# BREAK! Unable to output data for zip: 97857
# BREAK! Unable to output data for zip: 97862
# BREAK! Unable to output data for zip: 97864
# BREAK! Unable to output data for zip: 97868
# BREAK! Unable to output data for zip: 97870
# BREAK! Unable to output data for zip: 97874
# BREAK! Unable to output data for zip: 97877
# BREAK! Unable to output data for zip: 97880
# BREAK! Unable to output data for zip: 97884
# BREAK! Unable to output data for zip: 97885
# BREAK! Unable to output data for zip: 97886
# BREAK! Unable to output data for zip: 97901
# BREAK! Unable to output data for zip: 97903
# BREAK! Unable to output data for zip: 97904
# BREAK! Unable to output data for zip: 97905
# BREAK! Unable to output data for zip: 97906
# BREAK! Unable to output data for zip: 97907
# BREAK! Unable to output data for zip: 97908
# BREAK! Unable to output data for zip: 97909
# BREAK! Unable to output data for zip: 97910
# BREAK! Unable to output data for zip: 97911
# BREAK! Unable to output data for zip: 97913
# BREAK! Unable to output data for zip: 97920
# BREAK! Unable to output data for zip: 98019
# BREAK! Unable to output data for zip: 98045
# BREAK! Unable to output data for zip: 98068
# BREAK! Unable to output data for zip: 98224
# BREAK! Unable to output data for zip: 98237
# BREAK! Unable to output data for zip: 98241
# BREAK! Unable to output data for zip: 98244
# BREAK! Unable to output data for zip: 98251
# BREAK! Unable to output data for zip: 98252
# BREAK! Unable to output data for zip: 98256
# BREAK! Unable to output data for zip: 98267
# BREAK! Unable to output data for zip: 98283
# BREAK! Unable to output data for zip: 98288
# BREAK! Unable to output data for zip: 98294
# BREAK! Unable to output data for zip: 98304
# BREAK! Unable to output data for zip: 98323
# BREAK! Unable to output data for zip: 98325
# BREAK! Unable to output data for zip: 98330
# BREAK! Unable to output data for zip: 98336
# BREAK! Unable to output data for zip: 98339
# BREAK! Unable to output data for zip: 98355
# BREAK! Unable to output data for zip: 98356
# BREAK! Unable to output data for zip: 98357
# BREAK! Unable to output data for zip: 98361
# BREAK! Unable to output data for zip: 98368
# BREAK! Unable to output data for zip: 98376
# BREAK! Unable to output data for zip: 98377
# BREAK! Unable to output data for zip: 98381
# BREAK! Unable to output data for zip: 98526
# BREAK! Unable to output data for zip: 98527
# BREAK! Unable to output data for zip: 98533
# BREAK! Unable to output data for zip: 98552
# BREAK! Unable to output data for zip: 98562
# BREAK! Unable to output data for zip: 98564
# BREAK! Unable to output data for zip: 98575
# BREAK! Unable to output data for zip: 98577
# BREAK! Unable to output data for zip: 98581
# BREAK! Unable to output data for zip: 98585
# BREAK! Unable to output data for zip: 98586
# BREAK! Unable to output data for zip: 98587
# BREAK! Unable to output data for zip: 98601
# BREAK! Unable to output data for zip: 98603
# BREAK! Unable to output data for zip: 98605
# BREAK! Unable to output data for zip: 98610
# BREAK! Unable to output data for zip: 98611
# BREAK! Unable to output data for zip: 98612
# BREAK! Unable to output data for zip: 98616
# BREAK! Unable to output data for zip: 98619
# BREAK! Unable to output data for zip: 98620
# BREAK! Unable to output data for zip: 98621
# BREAK! Unable to output data for zip: 98626
# BREAK! Unable to output data for zip: 98632
# BREAK! Unable to output data for zip: 98640
# BREAK! Unable to output data for zip: 98641
# BREAK! Unable to output data for zip: 98645
# BREAK! Unable to output data for zip: 98647
# BREAK! Unable to output data for zip: 98648
# BREAK! Unable to output data for zip: 98649
# BREAK! Unable to output data for zip: 98650
# BREAK! Unable to output data for zip: 98651
# BREAK! Unable to output data for zip: 98811
# BREAK! Unable to output data for zip: 98812
# BREAK! Unable to output data for zip: 98813
# BREAK! Unable to output data for zip: 98814
# BREAK! Unable to output data for zip: 98816
# BREAK! Unable to output data for zip: 98817
# BREAK! Unable to output data for zip: 98822
# BREAK! Unable to output data for zip: 98824
# BREAK! Unable to output data for zip: 98826
# BREAK! Unable to output data for zip: 98830
# BREAK! Unable to output data for zip: 98831
# BREAK! Unable to output data for zip: 98833
# BREAK! Unable to output data for zip: 98834
# BREAK! Unable to output data for zip: 98843
# BREAK! Unable to output data for zip: 98846
# BREAK! Unable to output data for zip: 98852
# BREAK! Unable to output data for zip: 98856
# BREAK! Unable to output data for zip: 98858
# BREAK! Unable to output data for zip: 98859
# BREAK! Unable to output data for zip: 98862
# BREAK! Unable to output data for zip: 98903
# BREAK! Unable to output data for zip: 98922
# BREAK! Unable to output data for zip: 98925
# BREAK! Unable to output data for zip: 98929
# BREAK! Unable to output data for zip: 98930
# BREAK! Unable to output data for zip: 98932
# BREAK! Unable to output data for zip: 98935
# BREAK! Unable to output data for zip: 98937
# BREAK! Unable to output data for zip: 98938
# BREAK! Unable to output data for zip: 98940
# BREAK! Unable to output data for zip: 98941
# BREAK! Unable to output data for zip: 98943
# BREAK! Unable to output data for zip: 98950
# BREAK! Unable to output data for zip: 99006
# BREAK! Unable to output data for zip: 99009
# BREAK! Unable to output data for zip: 99017
# BREAK! Unable to output data for zip: 99018
# BREAK! Unable to output data for zip: 99032
# BREAK! Unable to output data for zip: 99033
# BREAK! Unable to output data for zip: 99039
# BREAK! Unable to output data for zip: 99040
# BREAK! Unable to output data for zip: 99101
# BREAK! Unable to output data for zip: 99103
# BREAK! Unable to output data for zip: 99105
# BREAK! Unable to output data for zip: 99109
# BREAK! Unable to output data for zip: 99110
# BREAK! Unable to output data for zip: 99114
# BREAK! Unable to output data for zip: 99115
# BREAK! Unable to output data for zip: 99116
# BREAK! Unable to output data for zip: 99117
# BREAK! Unable to output data for zip: 99118
# BREAK! Unable to output data for zip: 99119
# BREAK! Unable to output data for zip: 99121
# BREAK! Unable to output data for zip: 99122
# BREAK! Unable to output data for zip: 99123
# BREAK! Unable to output data for zip: 99124
# BREAK! Unable to output data for zip: 99125
# BREAK! Unable to output data for zip: 99126
# BREAK! Unable to output data for zip: 99128
# BREAK! Unable to output data for zip: 99129
# BREAK! Unable to output data for zip: 99131
# BREAK! Unable to output data for zip: 99133
# BREAK! Unable to output data for zip: 99134
# BREAK! Unable to output data for zip: 99135
# BREAK! Unable to output data for zip: 99136
# BREAK! Unable to output data for zip: 99137
# BREAK! Unable to output data for zip: 99138
# BREAK! Unable to output data for zip: 99139
# BREAK! Unable to output data for zip: 99140
# BREAK! Unable to output data for zip: 99141
# BREAK! Unable to output data for zip: 99143
# BREAK! Unable to output data for zip: 99144
# BREAK! Unable to output data for zip: 99146
# BREAK! Unable to output data for zip: 99147
# BREAK! Unable to output data for zip: 99148
# BREAK! Unable to output data for zip: 99149
# BREAK! Unable to output data for zip: 99150
# BREAK! Unable to output data for zip: 99151
# BREAK! Unable to output data for zip: 99152
# BREAK! Unable to output data for zip: 99153
# BREAK! Unable to output data for zip: 99154
# BREAK! Unable to output data for zip: 99155
# BREAK! Unable to output data for zip: 99156
# BREAK! Unable to output data for zip: 99157
# BREAK! Unable to output data for zip: 99158
# BREAK! Unable to output data for zip: 99159
# BREAK! Unable to output data for zip: 99160
# BREAK! Unable to output data for zip: 99166
# BREAK! Unable to output data for zip: 99167
# BREAK! Unable to output data for zip: 99169
# BREAK! Unable to output data for zip: 99170
# BREAK! Unable to output data for zip: 99171
# BREAK! Unable to output data for zip: 99173
# BREAK! Unable to output data for zip: 99174
# BREAK! Unable to output data for zip: 99176
# BREAK! Unable to output data for zip: 99180
# BREAK! Unable to output data for zip: 99181
# BREAK! Unable to output data for zip: 99185
# BREAK! Unable to output data for zip: 99321
# BREAK! Unable to output data for zip: 99322
# BREAK! Unable to output data for zip: 99324
# BREAK! Unable to output data for zip: 99326
# BREAK! Unable to output data for zip: 99328
# BREAK! Unable to output data for zip: 99329
# BREAK! Unable to output data for zip: 99333
# BREAK! Unable to output data for zip: 99335
# BREAK! Unable to output data for zip: 99341
# BREAK! Unable to output data for zip: 99344
# BREAK! Unable to output data for zip: 99347
# BREAK! Unable to output data for zip: 99348
# BREAK! Unable to output data for zip: 99349
# BREAK! Unable to output data for zip: 99356
# BREAK! Unable to output data for zip: 99357
# BREAK! Unable to output data for zip: 99359
# BREAK! Unable to output data for zip: 99360
# BREAK! Unable to output data for zip: 99361
# BREAK! Unable to output data for zip: 99362
# BREAK! Unable to output data for zip: 99371
# BREAK! Unable to output data for zip: 99401
# BREAK! Unable to output data for zip: 99503
# BREAK! Unable to output data for zip: 99510
# BREAK! Unable to output data for zip: 99519
# BREAK! Unable to output data for zip: 99550
# BREAK! Unable to output data for zip: 99552
# BREAK! Unable to output data for zip: 99553
# BREAK! Unable to output data for zip: 99554
# BREAK! Unable to output data for zip: 99557
# BREAK! Unable to output data for zip: 99558
# BREAK! Unable to output data for zip: 99566
# BREAK! Unable to output data for zip: 99568
# BREAK! Unable to output data for zip: 99572
# BREAK! Unable to output data for zip: 99573
# BREAK! Unable to output data for zip: 99574
# BREAK! Unable to output data for zip: 99575
# BREAK! Unable to output data for zip: 99576
# BREAK! Unable to output data for zip: 99578
# BREAK! Unable to output data for zip: 99579
# BREAK! Unable to output data for zip: 99581
# BREAK! Unable to output data for zip: 99583
# BREAK! Unable to output data for zip: 99585
# BREAK! Unable to output data for zip: 99586
# BREAK! Unable to output data for zip: 99588
# BREAK! Unable to output data for zip: 99590
# BREAK! Unable to output data for zip: 99602
# BREAK! Unable to output data for zip: 99605
# BREAK! Unable to output data for zip: 99607
# BREAK! Unable to output data for zip: 99609
# BREAK! Unable to output data for zip: 99613
# BREAK! Unable to output data for zip: 99615
# BREAK! Unable to output data for zip: 99620
# BREAK! Unable to output data for zip: 99622
# BREAK! Unable to output data for zip: 99624
# BREAK! Unable to output data for zip: 99625
# BREAK! Unable to output data for zip: 99626
# BREAK! Unable to output data for zip: 99627
# BREAK! Unable to output data for zip: 99638
# BREAK! Unable to output data for zip: 99639
# BREAK! Unable to output data for zip: 99640
# BREAK! Unable to output data for zip: 99643
# BREAK! Unable to output data for zip: 99647
# BREAK! Unable to output data for zip: 99648
# BREAK! Unable to output data for zip: 99656
# BREAK! Unable to output data for zip: 99657
# BREAK! Unable to output data for zip: 99665
# BREAK! Unable to output data for zip: 99666
# BREAK! Unable to output data for zip: 99667
# BREAK! Unable to output data for zip: 99668
# BREAK! Unable to output data for zip: 99672
# BREAK! Unable to output data for zip: 99674
# BREAK! Unable to output data for zip: 99677
# BREAK! Unable to output data for zip: 99678
# BREAK! Unable to output data for zip: 99679
# BREAK! Unable to output data for zip: 99680
# BREAK! Unable to output data for zip: 99682
# BREAK! Unable to output data for zip: 99683
# BREAK! Unable to output data for zip: 99688
# BREAK! Unable to output data for zip: 99691
# BREAK! Unable to output data for zip: 99693
# BREAK! Unable to output data for zip: 99695
# BREAK! Unable to output data for zip: 99701
# BREAK! Unable to output data for zip: 99702
# BREAK! Unable to output data for zip: 99703
# BREAK! Unable to output data for zip: 99704
# BREAK! Unable to output data for zip: 99705
# BREAK! Unable to output data for zip: 99706
# BREAK! Unable to output data for zip: 99709
# BREAK! Unable to output data for zip: 99712
# BREAK! Unable to output data for zip: 99714
# BREAK! Unable to output data for zip: 99720
# BREAK! Unable to output data for zip: 99721
# BREAK! Unable to output data for zip: 99722
# BREAK! Unable to output data for zip: 99723
# BREAK! Unable to output data for zip: 99724
# BREAK! Unable to output data for zip: 99726
# BREAK! Unable to output data for zip: 99727
# BREAK! Unable to output data for zip: 99729
# BREAK! Unable to output data for zip: 99730
# BREAK! Unable to output data for zip: 99732
# BREAK! Unable to output data for zip: 99733
# BREAK! Unable to output data for zip: 99734
# BREAK! Unable to output data for zip: 99736
# BREAK! Unable to output data for zip: 99737
# BREAK! Unable to output data for zip: 99738
# BREAK! Unable to output data for zip: 99739
# BREAK! Unable to output data for zip: 99740
# BREAK! Unable to output data for zip: 99741
# BREAK! Unable to output data for zip: 99743
# BREAK! Unable to output data for zip: 99744
# BREAK! Unable to output data for zip: 99745
# BREAK! Unable to output data for zip: 99746
# BREAK! Unable to output data for zip: 99747
# BREAK! Unable to output data for zip: 99748
# BREAK! Unable to output data for zip: 99749
# BREAK! Unable to output data for zip: 99750
# BREAK! Unable to output data for zip: 99751
# BREAK! Unable to output data for zip: 99752
# BREAK! Unable to output data for zip: 99754
# BREAK! Unable to output data for zip: 99755
# BREAK! Unable to output data for zip: 99756
# BREAK! Unable to output data for zip: 99757
# BREAK! Unable to output data for zip: 99758
# BREAK! Unable to output data for zip: 99759
# BREAK! Unable to output data for zip: 99760
# BREAK! Unable to output data for zip: 99761
# BREAK! Unable to output data for zip: 99762
# BREAK! Unable to output data for zip: 99763
# BREAK! Unable to output data for zip: 99764
# BREAK! Unable to output data for zip: 99765
# BREAK! Unable to output data for zip: 99766
# BREAK! Unable to output data for zip: 99767
# BREAK! Unable to output data for zip: 99768
# BREAK! Unable to output data for zip: 99769
# BREAK! Unable to output data for zip: 99770
# BREAK! Unable to output data for zip: 99771
# BREAK! Unable to output data for zip: 99772
# BREAK! Unable to output data for zip: 99773
# BREAK! Unable to output data for zip: 99774
# BREAK! Unable to output data for zip: 99775
# BREAK! Unable to output data for zip: 99776
# BREAK! Unable to output data for zip: 99777
# BREAK! Unable to output data for zip: 99778
# BREAK! Unable to output data for zip: 99780
# BREAK! Unable to output data for zip: 99781
# BREAK! Unable to output data for zip: 99782
# BREAK! Unable to output data for zip: 99783
# BREAK! Unable to output data for zip: 99785
# BREAK! Unable to output data for zip: 99786
# BREAK! Unable to output data for zip: 99788
# BREAK! Unable to output data for zip: 99789
# BREAK! Unable to output data for zip: 99790
# BREAK! Unable to output data for zip: 99791
# BREAK! Unable to output data for zip: 99826
# BREAK! Unable to output data for zip: 99836
# BREAK! Unable to output data for zip: 99841
# BREAK! Unable to output data for zip: 99901
# BREAK! Unable to output data for zip: 99903
# BREAK! Unable to output data for zip: 99918
# BREAK! Unable to output data for zip: 99919
# BREAK! Unable to output data for zip: 99927
# BREAK! Unable to output data for zip: 99929
